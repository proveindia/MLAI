# %%
# !pip install -U kaleido
import seaborn as sns
import pandas as pd
sns.set(font_scale=1.5)
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import plotly.graph_objects as go
import plotly.express as px
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.utils import shuffle
from sklearn.linear_model import Ridge
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SequentialFeatureSelector
# Out:
# Collecting kaleido
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl.metadata (15 kB)
# Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 7.0 MB/s eta 0:00:00
# Installing collected packages: kaleido
# Successfully installed kaleido-0.2.1

# %%
#np.random.seed(105)
np.random.seed(319)

# %%
#load the fuel dataset, and drop any rows that have missing data
vehicle_data = sns.load_dataset('mpg').dropna()
vehicle_data  = vehicle_data.rename(columns = {"horsepower": "hp"})
px.scatter(vehicle_data, x = "hp", y = "mpg")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="55ee6cf3-9ac7-4b6f-9922-7313a45b3b7e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("55ee6cf3-9ac7-4b6f-9922-7313a45b3b7e")) {                    Plotly.newPlot(                        "55ee6cf3-9ac7-4b6f-9922-7313a45b3b7e",                        [{"hovertemplate":"hp=%{x}\u003cbr\u003empg=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[130.0,165.0,150.0,150.0,140.0,198.0,220.0,215.0,225.0,190.0,170.0,160.0,150.0,225.0,95.0,95.0,97.0,85.0,88.0,46.0,87.0,90.0,95.0,113.0,90.0,215.0,200.0,210.0,193.0,88.0,90.0,95.0,100.0,105.0,100.0,88.0,100.0,165.0,175.0,153.0,150.0,180.0,170.0,175.0,110.0,72.0,100.0,88.0,86.0,90.0,70.0,76.0,65.0,69.0,60.0,70.0,95.0,80.0,54.0,90.0,86.0,165.0,175.0,150.0,153.0,150.0,208.0,155.0,160.0,190.0,97.0,150.0,130.0,140.0,150.0,112.0,76.0,87.0,69.0,86.0,92.0,97.0,80.0,88.0,175.0,150.0,145.0,137.0,150.0,198.0,150.0,158.0,150.0,215.0,225.0,175.0,105.0,100.0,100.0,88.0,95.0,46.0,150.0,167.0,170.0,180.0,100.0,88.0,72.0,94.0,90.0,85.0,107.0,90.0,145.0,230.0,49.0,75.0,91.0,112.0,150.0,110.0,122.0,180.0,95.0,100.0,100.0,67.0,80.0,65.0,75.0,100.0,110.0,105.0,140.0,150.0,150.0,140.0,150.0,83.0,67.0,78.0,52.0,61.0,75.0,75.0,75.0,97.0,93.0,67.0,95.0,105.0,72.0,72.0,170.0,145.0,150.0,148.0,110.0,105.0,110.0,95.0,110.0,110.0,129.0,75.0,83.0,100.0,78.0,96.0,71.0,97.0,97.0,70.0,90.0,95.0,88.0,98.0,115.0,53.0,86.0,81.0,92.0,79.0,83.0,140.0,150.0,120.0,152.0,100.0,105.0,81.0,90.0,52.0,60.0,70.0,53.0,100.0,78.0,110.0,95.0,71.0,70.0,75.0,72.0,102.0,150.0,88.0,108.0,120.0,180.0,145.0,130.0,150.0,68.0,80.0,58.0,96.0,70.0,145.0,110.0,145.0,130.0,110.0,105.0,100.0,98.0,180.0,170.0,190.0,149.0,78.0,88.0,75.0,89.0,63.0,83.0,67.0,78.0,97.0,110.0,110.0,48.0,66.0,52.0,70.0,60.0,110.0,140.0,139.0,105.0,95.0,85.0,88.0,100.0,90.0,105.0,85.0,110.0,120.0,145.0,165.0,139.0,140.0,68.0,95.0,97.0,75.0,95.0,105.0,85.0,97.0,103.0,125.0,115.0,133.0,71.0,68.0,115.0,85.0,88.0,90.0,110.0,130.0,129.0,138.0,135.0,155.0,142.0,125.0,150.0,71.0,65.0,80.0,80.0,77.0,125.0,71.0,90.0,70.0,70.0,65.0,69.0,90.0,115.0,115.0,90.0,76.0,60.0,70.0,65.0,90.0,88.0,90.0,90.0,78.0,90.0,75.0,92.0,75.0,65.0,105.0,65.0,48.0,48.0,67.0,67.0,67.0,67.0,62.0,132.0,100.0,88.0,72.0,84.0,84.0,92.0,110.0,84.0,58.0,64.0,60.0,67.0,65.0,62.0,68.0,63.0,65.0,65.0,74.0,75.0,75.0,100.0,74.0,80.0,76.0,116.0,120.0,110.0,105.0,88.0,85.0,88.0,88.0,88.0,85.0,84.0,90.0,92.0,74.0,68.0,68.0,63.0,70.0,88.0,75.0,70.0,67.0,67.0,67.0,110.0,85.0,92.0,112.0,96.0,84.0,90.0,86.0,52.0,84.0,79.0,82.0],"xaxis":"x","y":[18.0,15.0,18.0,16.0,17.0,15.0,14.0,14.0,14.0,15.0,15.0,14.0,15.0,14.0,24.0,22.0,18.0,21.0,27.0,26.0,25.0,24.0,25.0,26.0,21.0,10.0,10.0,11.0,9.0,27.0,28.0,25.0,19.0,16.0,17.0,19.0,18.0,14.0,14.0,14.0,14.0,12.0,13.0,13.0,18.0,22.0,19.0,18.0,23.0,28.0,30.0,30.0,31.0,35.0,27.0,26.0,24.0,25.0,23.0,20.0,21.0,13.0,14.0,15.0,14.0,17.0,11.0,13.0,12.0,13.0,19.0,15.0,13.0,13.0,14.0,18.0,22.0,21.0,26.0,22.0,28.0,23.0,28.0,27.0,13.0,14.0,13.0,14.0,15.0,12.0,13.0,13.0,14.0,13.0,12.0,13.0,18.0,16.0,18.0,18.0,23.0,26.0,11.0,12.0,13.0,12.0,18.0,20.0,21.0,22.0,18.0,19.0,21.0,26.0,15.0,16.0,29.0,24.0,20.0,19.0,15.0,24.0,20.0,11.0,20.0,19.0,15.0,31.0,26.0,32.0,25.0,16.0,16.0,18.0,16.0,13.0,14.0,14.0,14.0,29.0,26.0,26.0,31.0,32.0,28.0,24.0,26.0,24.0,26.0,31.0,19.0,18.0,15.0,15.0,16.0,15.0,16.0,14.0,17.0,16.0,15.0,18.0,21.0,20.0,13.0,29.0,23.0,20.0,23.0,24.0,25.0,24.0,18.0,29.0,19.0,23.0,23.0,22.0,25.0,33.0,28.0,25.0,25.0,26.0,27.0,17.5,16.0,15.5,14.5,22.0,22.0,24.0,22.5,29.0,24.5,29.0,33.0,20.0,18.0,18.5,17.5,29.5,32.0,28.0,26.5,20.0,13.0,19.0,19.0,16.5,16.5,13.0,13.0,13.0, ...

# %%
vehicle_data
# Out:
#       mpg  cylinders  displacement     hp  weight  acceleration  model_year  \
# 0    18.0          8         307.0  130.0    3504          12.0          70
# 1    15.0          8         350.0  165.0    3693          11.5          70
# 2    18.0          8         318.0  150.0    3436          11.0          70
# 3    16.0          8         304.0  150.0    3433          12.0          70
# 4    17.0          8         302.0  140.0    3449          10.5          70
# ..    ...        ...           ...    ...     ...           ...         ...
# 393  27.0          4         140.0   86.0    2790          15.6          82
# 394  44.0          4          97.0   52.0    2130          24.6          82
# 395  32.0          4         135.0   84.0    2295          11.6          82
# 396  28.0          4         120.0   79.0    2625          18.6          82
# 397  31.0          4         119.0   82.0    2720          19.4          82
#
#      origin                       name
# 0       usa  chevrolet chevelle malibu
# 1       usa          buick skylark 320
# 2       usa         plymouth satellite
# 3       usa              amc rebel sst
# 4       usa                ford torino
# ..      ...                        ...
# 393     usa            ford mustang gl
# 394  europe                  vw pickup
# 395     usa              dodge rampage
# 396     usa                ford ranger
# 397     usa                 chevy s-10
#
# [392 rows x 9 columns]

# %%
vehicle_data[["hp", "weight"]]
# Out:
#         hp  weight
# 0    130.0    3504
# 1    165.0    3693
# 2    150.0    3436
# 3    150.0    3433
# 4    140.0    3449
# ..     ...     ...
# 393   86.0    2790
# 394   52.0    2130
# 395   84.0    2295
# 396   79.0    2625
# 397   82.0    2720
#
# [392 rows x 2 columns]

# %%
poly_transform = PolynomialFeatures(degree = 2, include_bias = False)
vehicle_data_with_squared_features = \
             pd.DataFrame(poly_transform.fit_transform(vehicle_data[["hp", "weight"]]),
             columns = poly_transform.get_feature_names_out())

# %%
vehicle_data_with_squared_features
# Out:
#         hp  weight     hp^2  hp weight    weight^2
# 0    130.0  3504.0  16900.0   455520.0  12278016.0
# 1    165.0  3693.0  27225.0   609345.0  13638249.0
# 2    150.0  3436.0  22500.0   515400.0  11806096.0
# 3    150.0  3433.0  22500.0   514950.0  11785489.0
# 4    140.0  3449.0  19600.0   482860.0  11895601.0
# ..     ...     ...      ...        ...         ...
# 387   86.0  2790.0   7396.0   239940.0   7784100.0
# 388   52.0  2130.0   2704.0   110760.0   4536900.0
# 389   84.0  2295.0   7056.0   192780.0   5267025.0
# 390   79.0  2625.0   6241.0   207375.0   6890625.0
# 391   82.0  2720.0   6724.0   223040.0   7398400.0
#
# [392 rows x 5 columns]

# %%
poly_transform = PolynomialFeatures(degree = 3, include_bias = False)
vehicle_data_with_cubic_features = \
             pd.DataFrame(poly_transform.fit_transform(vehicle_data[["hp", "weight"]]),
             columns = poly_transform.get_feature_names_out())

# %%
vehicle_data_with_cubic_features
# Out:
#         hp  weight     hp^2  hp weight    weight^2       hp^3  hp^2 weight  \
# 0    130.0  3504.0  16900.0   455520.0  12278016.0  2197000.0   59217600.0
# 1    165.0  3693.0  27225.0   609345.0  13638249.0  4492125.0  100541925.0
# 2    150.0  3436.0  22500.0   515400.0  11806096.0  3375000.0   77310000.0
# 3    150.0  3433.0  22500.0   514950.0  11785489.0  3375000.0   77242500.0
# 4    140.0  3449.0  19600.0   482860.0  11895601.0  2744000.0   67600400.0
# ..     ...     ...      ...        ...         ...        ...          ...
# 387   86.0  2790.0   7396.0   239940.0   7784100.0   636056.0   20634840.0
# 388   52.0  2130.0   2704.0   110760.0   4536900.0   140608.0    5759520.0
# 389   84.0  2295.0   7056.0   192780.0   5267025.0   592704.0   16193520.0
# 390   79.0  2625.0   6241.0   207375.0   6890625.0   493039.0   16382625.0
# 391   82.0  2720.0   6724.0   223040.0   7398400.0   551368.0   18289280.0
#
#       hp weight^2      weight^3
# 0    1.596142e+09  4.302217e+10
# 1    2.250311e+09  5.036605e+10
# 2    1.770914e+09  4.056575e+10
# 3    1.767823e+09  4.045958e+10
# 4    1.665384e+09  4.102793e+10
# ..            ...           ...
# 387  6.694326e+08  2.171764e+10
# 388  2.359188e+08  9.663597e+09
# 389  4.424301e+08  1.208782e+10
# 390  5.443594e+08  1.808789e+10
# 391  6.066688e+08  2.012365e+10
#
# [392 rows x 9 columns]

# %%
vehicle_data[["hp", "weight", "displacement"]]
# Out:
#         hp  weight  displacement
# 0    130.0    3504         307.0
# 1    165.0    3693         350.0
# 2    150.0    3436         318.0
# 3    150.0    3433         304.0
# 4    140.0    3449         302.0
# ..     ...     ...           ...
# 393   86.0    2790         140.0
# 394   52.0    2130          97.0
# 395   84.0    2295         135.0
# 396   79.0    2625         120.0
# 397   82.0    2720         119.0
#
# [392 rows x 3 columns]

# %%
poly_transform = PolynomialFeatures(degree = 2, include_bias = False)
vehicle_data_with_squared_features = \
             pd.DataFrame(poly_transform.fit_transform(vehicle_data[["hp", "weight", "displacement"]]),
             columns = poly_transform.get_feature_names_out())

# %%
vehicle_data_with_squared_features
# Out:
#         hp  weight  displacement     hp^2  hp weight  hp displacement  \
# 0    130.0  3504.0         307.0  16900.0   455520.0          39910.0
# 1    165.0  3693.0         350.0  27225.0   609345.0          57750.0
# 2    150.0  3436.0         318.0  22500.0   515400.0          47700.0
# 3    150.0  3433.0         304.0  22500.0   514950.0          45600.0
# 4    140.0  3449.0         302.0  19600.0   482860.0          42280.0
# ..     ...     ...           ...      ...        ...              ...
# 387   86.0  2790.0         140.0   7396.0   239940.0          12040.0
# 388   52.0  2130.0          97.0   2704.0   110760.0           5044.0
# 389   84.0  2295.0         135.0   7056.0   192780.0          11340.0
# 390   79.0  2625.0         120.0   6241.0   207375.0           9480.0
# 391   82.0  2720.0         119.0   6724.0   223040.0           9758.0
#
#        weight^2  weight displacement  displacement^2
# 0    12278016.0            1075728.0         94249.0
# 1    13638249.0            1292550.0        122500.0
# 2    11806096.0            1092648.0        101124.0
# 3    11785489.0            1043632.0         92416.0
# 4    11895601.0            1041598.0         91204.0
# ..          ...                  ...             ...
# 387   7784100.0             390600.0         19600.0
# 388   4536900.0             206610.0          9409.0
# 389   5267025.0             309825.0         18225.0
# 390   6890625.0             315000.0         14400.0
# 391   7398400.0             323680.0         14161.0
#
# [392 rows x 9 columns]

# %% [markdown]
# ### Video 2: Forward Selection

# %%
# for reasons that will become clear later, we set up the training and dev indices as separate arrays first
all_indices = range(0, len(vehicle_data))
all_indices = shuffle(all_indices)
training_indices, dev_indices = np.split(all_indices, [320])
training_vehicle_data = vehicle_data.iloc[training_indices]
dev_vehicle_data = vehicle_data.iloc[dev_indices]

# %%
best_old_model = Pipeline([
    ('josh_transform', PolynomialFeatures(degree = 2, include_bias = False)),
    ('josh_regression', LinearRegression())
])
best_old_model.fit(training_vehicle_data[["hp"]], training_vehicle_data["mpg"])
# Out:
# Pipeline(steps=[('josh_transform', PolynomialFeatures(include_bias=False)),
#                 ('josh_regression', LinearRegression())])

# %%
mean_squared_error(best_old_model.predict(training_vehicle_data[["hp"]]), training_vehicle_data["mpg"])
# Out:
# 18.948788936311274

# %%
mean_squared_error(best_old_model.predict(dev_vehicle_data[["hp"]]), dev_vehicle_data["mpg"]) #e1
# Out:
# 19.453686826337034

# %%
numeric_features = ["cylinders", "displacement", "hp", "weight", "acceleration"]
massive_new_model = Pipeline([
    ('josh_transform', PolynomialFeatures(degree = 3, include_bias = False)),
    ('josh_regression', LinearRegression())
])
massive_new_model.fit(training_vehicle_data[numeric_features], training_vehicle_data["mpg"])
# Out:
# Pipeline(steps=[('josh_transform',
#                  PolynomialFeatures(degree=3, include_bias=False)),
#                 ('josh_regression', LinearRegression())])

# %%
mean_squared_error(massive_new_model.predict(training_vehicle_data[numeric_features]), training_vehicle_data["mpg"])
# Out:
# 10.151573882857129

# %%
mean_squared_error(massive_new_model.predict(dev_vehicle_data[numeric_features]), dev_vehicle_data["mpg"]) #e2
# Out:
# 18.193708544421117

# %% [markdown]
# ### Video 3: SequentialFeatureSelection

# %%
poly3 = PolynomialFeatures(degree = 3, include_bias = False)
all_degree_3_combinations = poly3.fit_transform(vehicle_data[["cylinders", "displacement", "hp",
                                                              "weight", "acceleration"]])
all_degree_3_combinations = pd.DataFrame(all_degree_3_combinations, columns = poly3.get_feature_names_out())

# %%
all_degree_3_combinations
# Out:
#      cylinders  displacement     hp  weight  acceleration  cylinders^2  \
# 0          8.0         307.0  130.0  3504.0          12.0         64.0
# 1          8.0         350.0  165.0  3693.0          11.5         64.0
# 2          8.0         318.0  150.0  3436.0          11.0         64.0
# 3          8.0         304.0  150.0  3433.0          12.0         64.0
# 4          8.0         302.0  140.0  3449.0          10.5         64.0
# ..         ...           ...    ...     ...           ...          ...
# 387        4.0         140.0   86.0  2790.0          15.6         16.0
# 388        4.0          97.0   52.0  2130.0          24.6         16.0
# 389        4.0         135.0   84.0  2295.0          11.6         16.0
# 390        4.0         120.0   79.0  2625.0          18.6         16.0
# 391        4.0         119.0   82.0  2720.0          19.4         16.0
#
#      cylinders displacement  cylinders hp  cylinders weight  \
# 0                    2456.0        1040.0           28032.0
# 1                    2800.0        1320.0           29544.0
# 2                    2544.0        1200.0           27488.0
# 3                    2432.0        1200.0           27464.0
# 4                    2416.0        1120.0           27592.0
# ..                      ...           ...               ...
# 387                   560.0         344.0           11160.0
# 388                   388.0         208.0            8520.0
# 389                   540.0         336.0            9180.0
# 390                   480.0         316.0           10500.0
# 391                   476.0         328.0           10880.0
#
#      cylinders acceleration  ...       hp^3  hp^2 weight  hp^2 acceleration  \
# 0                      96.0  ...  2197000.0   59217600.0           202800.0
# 1                      92.0  ...  4492125.0  100541925.0           313087.5
# 2                      88.0  ...  3375000.0   77310000.0           247500.0
# 3                      96.0  ...  3375000.0   77242500.0           270000.0
# 4                      84.0  ...  2744000.0   67600400.0           205800.0
# ..                      ...  ...        ...          ...                ...
# 387                    62.4  ...   636056.0   20634840.0           115377.6
# 388                    98.4  ...   140608.0    5759520.0            66518.4
# 389                    46.4  ...   592704.0   16193520.0            81849.6
# 390                    74.4  ...   493039.0   16382625.0           116082.6
# 391                    77.6  ...   551368.0   18289280.0           130445.6
#
#       hp weight^2  hp weight acceleration  hp acceleration^2      weight^3  \
# 0    1.596142e+09               5466240.0           18720.00  4.302217e+10
# 1    2.250311e+09               7007467.5           21821.25  5.036605e+10
# 2    1.770914e+09               5669400.0           18150.00  4.056575e+10
# 3    1.767823e+09               6179400.0           21600.00  4.045958e+10
# 4    1.665384e+09               5070030.0           15435.00  4.102793e+10
# ..            ...                     ...                ...           ...
# 387  6.694326e+08               3743064.0           20928.96  2.171764e+10
# 388  2.359188e+08               2724696.0           31468.32  9.663597e+09
# 389  4.424301e+08               2236248.0           11303.04  1.208782e+10
# 390  5.443594e+08               3857175.0           27330.84  1.808789e+10
# 391  6.066688e+08               4326976.0           30861.52  2.012365e+10
#
#      weight^2 acceleration  weight acceleration^2  acceleration^3
# 0              147336192.0              504576.00        1728.000
# 1              156839863.5              488399.25        1520.875
# 2              129867056.0              415756.00        1331.000
# 3              141425868.0              494352.00        1728.000
# 4              124903810.5              380252.25        1157.625
# ..                     ...                    ...             ...
# 387            121431960.0              678974.40        3796.416
# 388            111607740.0             1288990.80       14886.936
# 389             61097490.0              308815.20        1560.896
# 390            128165625.0              908145.00        6434.856
# 391            143528960.0             1023699.20        7301.384
#
# [392 rows x 55 columns]

# %%
#all_indices = range(0, len(vehicle_data))
#all_indices = shuffle(all_indices)
#training_indices, dev_indices = np.split(all_indices, [320])

# %%
feature_select = SequentialFeatureSelector(LinearRegression(),
                                           scoring='neg_mean_squared_error',
                                           cv=[[training_indices, dev_indices]],
                                           n_features_to_select = 4)
feature_select.fit(all_degree_3_combinations, vehicle_data["mpg"])
# Out:
# SequentialFeatureSelector(cv=[[array([145, 390, 224,  59,  55, 229, 341, 140, 273, 311, 128,  36, 214,
#        369, 263, 313, 158, 233,  71, 148, 213, 185, 156, 354, 312,   0,
#        372,  45, 240, 391, 247, 320, 331, 359, 243, 256,  94, 261, 125,
#        114, 365, 167, 235, 193, 286,  93,  54, 241, 321, 111,  79, 303,
#         82, 228,  37, 131, 246, 178, 370, 309, 144, 382,  13, 376, 310,
#         42, 157, 348, 319, 336, 342, 116, 216, 267, 237, 149, 386, 196,
#        101, 207, 262, 297...
#                                array([ 49, 364,  38, 307, 164, 345, 181, 218, 202, 389, 211, 371, 290,
#        264, 227,  29, 161, 368, 118, 147, 356,  10, 257, 339, 323, 304,
#        355, 102, 268,  53, 324,  31, 242, 362, 226, 180, 184, 204,  62,
#         89,  91, 334,  77, 377, 137, 190,  87,  41, 335, 231, 122, 294,
#        107, 280, 177,  25, 198, 274,  14, 173,  64, 159, 318,   4, 238,
#        194, 106,  86,  81, 367, 223, 289])]],
#                           estimator=LinearRegression(), n_features_to_select=4,
#                           scoring='neg_mean_squared_error')

# %%
feature_select = SequentialFeatureSelector(estimator = LinearRegression(),
                                           scoring='neg_mean_squared_error',
                                           cv=[[training_indices, dev_indices]],
                                           n_features_to_select = 4)

best_four = pd.DataFrame(feature_select.fit_transform(all_degree_3_combinations, vehicle_data["mpg"]),
                         columns = feature_select.get_feature_names_out())

# %%
best_four
# the specific four parameters you observe will depend heavily on whatever training sample you happen to have split off from the full dataset
# Out:
#         hp  weight  hp weight    weight^2
# 0    130.0  3504.0   455520.0  12278016.0
# 1    165.0  3693.0   609345.0  13638249.0
# 2    150.0  3436.0   515400.0  11806096.0
# 3    150.0  3433.0   514950.0  11785489.0
# 4    140.0  3449.0   482860.0  11895601.0
# ..     ...     ...        ...         ...
# 387   86.0  2790.0   239940.0   7784100.0
# 388   52.0  2130.0   110760.0   4536900.0
# 389   84.0  2295.0   192780.0   5267025.0
# 390   79.0  2625.0   207375.0   6890625.0
# 391   82.0  2720.0   223040.0   7398400.0
#
# [392 rows x 4 columns]

# %%
len(vehicle_data)
# Out:
# 392

# %%
best_four_sfs_model = LinearRegression()
best_four_sfs_model.fit(best_four.iloc[training_indices], vehicle_data.iloc[training_indices]["mpg"])
# Out:
# LinearRegression()

# %%
mean_squared_error(best_four_sfs_model.predict(best_four.iloc[training_indices]),
                                               vehicle_data.iloc[training_indices]["mpg"])
# Out:
# 15.144620842922468

# %%
mean_squared_error(best_four_sfs_model.predict(best_four.iloc[dev_indices]),
                                               vehicle_data.iloc[dev_indices]["mpg"]) #e3
# Out:
# 16.319391679212913

# %% [markdown]
# ### Video 4: Regularization

# %% [markdown]
# ### Regularization on a Simple Model with 5 Features

# %%
lm_model = LinearRegression()
lm_model.fit(training_vehicle_data[numeric_features], training_vehicle_data["mpg"])
# Out:
# LinearRegression()

# %%
param_df = pd.DataFrame([lm_model.coef_], columns = numeric_features)
param_df
# Out:
#    cylinders  displacement        hp    weight  acceleration
# 0   -0.56448      0.000087 -0.046525 -0.004874     -0.128084

# %%
lm_with_ridge_model = Ridge(alpha = 0.001)
lm_with_ridge_model.fit(training_vehicle_data[numeric_features], training_vehicle_data["mpg"])
# Out:
# Ridge(alpha=0.001)

# %%
param_df = pd.DataFrame([lm_with_ridge_model.coef_], columns = numeric_features)
param_df
# Out:
#    cylinders  displacement        hp    weight  acceleration
# 0  -0.564474      0.000087 -0.046525 -0.004874     -0.128084

# %%
lm_with_ridge_model = Ridge(alpha = 100)
lm_with_ridge_model.fit(training_vehicle_data[numeric_features], training_vehicle_data["mpg"])
# Out:
# Ridge(alpha=100)

# %%
param_df = pd.DataFrame([lm_with_ridge_model.coef_], columns = numeric_features)
param_df
# Out:
#    cylinders  displacement        hp    weight  acceleration
# 0  -0.262533     -0.004226 -0.043977 -0.005005     -0.110041

# %%
lm_with_ridge_model.coef_
# Out:
# array([-0.26253268, -0.00422633, -0.04397693, -0.00500508, -0.11004116])

# %%
def get_parameters_for_given_alpha(alpha):
    lm_with_ridge_model = Ridge(alpha = alpha)
    lm_with_ridge_model.fit(training_vehicle_data[numeric_features], training_vehicle_data["mpg"])
    return alpha, *lm_with_ridge_model.coef_

# %%
param_df = pd.DataFrame([get_parameters_for_given_alpha(alpha) for alpha in [0.01, 0.1, 1, 10, 100, 1000, 10000]],
                        columns = ["alpha", *numeric_features])
param_df["SoS"] = param_df["cylinders"]**2 + param_df["displacement"]**2 + param_df["hp"]**2 + \
                  param_df["weight"]**2 + param_df["acceleration"]**2
param_df
# Out:
#       alpha  cylinders  displacement        hp    weight  acceleration  \
# 0      0.01  -0.564416      0.000086 -0.046525 -0.004874     -0.128082
# 1      0.10  -0.563834      0.000078 -0.046521 -0.004874     -0.128058
# 2      1.00  -0.558085     -0.000005 -0.046481 -0.004876     -0.127822
# 3     10.00  -0.506427     -0.000751 -0.046119 -0.004896     -0.125592
# 4    100.00  -0.262533     -0.004226 -0.043977 -0.005005     -0.110041
# 5   1000.00  -0.044487     -0.007014 -0.038392 -0.005229     -0.054869
# 6  10000.00  -0.004729     -0.007734 -0.031588 -0.005424     -0.007440
#
#         SoS
# 0  0.337158
# 1  0.336496
# 2  0.329982
# 3  0.274393
# 4  0.083009
# 5  0.006540
# 6  0.001165

# %%
param_df = pd.DataFrame([get_parameters_for_given_alpha(alpha) for alpha in [0.01, 0.1, 1, 10, 100, 1000, 10000, 1e5, 1e6, 1e7]],
                        columns = ["alpha", *numeric_features])
param_df["SoS"] = param_df["cylinders"]**2 + param_df["displacement"]**2 + param_df["hp"]**2 + \
                  param_df["weight"]**2 + param_df["acceleration"]**2
param_df
# Out:
#          alpha  cylinders  displacement        hp    weight  acceleration  \
# 0         0.01  -0.564416      0.000086 -0.046525 -0.004874     -0.128082
# 1         0.10  -0.563834      0.000078 -0.046521 -0.004874     -0.128058
# 2         1.00  -0.558085     -0.000005 -0.046481 -0.004876     -0.127822
# 3        10.00  -0.506427     -0.000751 -0.046119 -0.004896     -0.125592
# 4       100.00  -0.262533     -0.004226 -0.043977 -0.005005     -0.110041
# 5      1000.00  -0.044487     -0.007014 -0.038392 -0.005229     -0.054869
# 6     10000.00  -0.004729     -0.007734 -0.031588 -0.005424     -0.007440
# 7    100000.00  -0.000554     -0.009375 -0.017656 -0.005784      0.000430
# 8   1000000.00  -0.000112     -0.005178 -0.004158 -0.006778      0.000259
# 9  10000000.00  -0.000026     -0.001464 -0.000755 -0.007058      0.000044
#
#         SoS
# 0  0.337158
# 1  0.336496
# 2  0.329982
# 3  0.274393
# 4  0.083009
# 5  0.006540
# 6  0.001165
# 7  0.000434
# 8  0.000090
# 9  0.000053

# %%
def get_parameters_and_training_MSE_for_given_alpha(alpha):
    lm_with_ridge_model = Ridge(alpha = alpha)
    lm_with_ridge_model.fit(training_vehicle_data[numeric_features], training_vehicle_data["mpg"])
    training_mse = mean_squared_error(lm_with_ridge_model.predict(training_vehicle_data[numeric_features]), training_vehicle_data["mpg"])
    return alpha, *lm_with_ridge_model.coef_, training_mse

# %%
param_df = pd.DataFrame([get_parameters_and_training_MSE_for_given_alpha(alpha) for alpha in [0.01, 0.1, 1, 10, 100, 1000, 10000, 1e5, 1e6, 1e7, 1e8]],
                        columns = ["alpha", *numeric_features, "Training MSE"])
param_df

fig = px.line(param_df, x = "alpha", y = "Training MSE", log_x = True, markers = True)
fig.write_image("MSE_vs_alpha_most_basic.png", scale = 3)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3ca7b1b1-9608-4e9e-96d9-3507bd8055f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ca7b1b1-9608-4e9e-96d9-3507bd8055f0")) {                    Plotly.newPlot(                        "3ca7b1b1-9608-4e9e-96d9-3507bd8055f0",                        [{"hovertemplate":"alpha=%{x}\u003cbr\u003eTraining MSE=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":[0.01,0.1,1.0,10.0,100.0,1000.0,10000.0,100000.0,1000000.0,10000000.0,100000000.0],"xaxis":"x","y":[17.010202260722366,17.010202374529868,17.01021352409776,17.011131349262637,17.035624073094514,17.0958616200952,17.133729996886583,17.22055382988603,17.528164823886687,17.815608877479413,21.522141885280938],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y": ...

# %%
param_df = pd.DataFrame([get_parameters_and_training_MSE_for_given_alpha(alpha) for alpha in [0.01, 0.1, 1, 10, 100, 1000, 10000, 1e5, 1e6, 1e7, 1e8]],
                        columns = ["alpha", *numeric_features, "Training MSE"])
param_df["1/alpha"] = 1.0/param_df["alpha"]

fig = px.line(param_df, x = "1/alpha", y = "Training MSE", log_x = True, markers = True)
fig.write_image("MSE_vs_1_over_alpha_most_basic.png", scale = 3)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f721b643-5280-4253-abb7-7c997c8a03a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f721b643-5280-4253-abb7-7c997c8a03a2")) {                    Plotly.newPlot(                        "f721b643-5280-4253-abb7-7c997c8a03a2",                        [{"hovertemplate":"1\u002falpha=%{x}\u003cbr\u003eTraining MSE=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":[100.0,10.0,1.0,0.1,0.01,0.001,0.0001,0.00001,1e-6,1e-7,1e-8],"xaxis":"x","y":[17.010202260722366,17.010202374529868,17.01021352409776,17.011131349262637,17.035624073094514,17.0958616200952,17.133729996886583,17.22055382988603,17.528164823886687,17.815608877479413,21.522141885280938],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3 ...

# %%
param_df = pd.DataFrame([get_parameters_and_training_MSE_for_given_alpha(alpha) for alpha in 10**np.linspace(-2, 8, 100)],
                        columns = ["alpha", *numeric_features, "Training MSE"])
param_df["1/alpha"] = 1.0/param_df["alpha"]

fig = px.line(param_df, x = "1/alpha", y = "Training MSE", log_x = True, markers = True)
fig.write_image("MSE_vs_1_over_alpha_smooth.png", scale = 3)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="de5348a2-1b90-4892-a8ab-87610c0323b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("de5348a2-1b90-4892-a8ab-87610c0323b8")) {                    Plotly.newPlot(                        "de5348a2-1b90-4892-a8ab-87610c0323b8",                        [{"hovertemplate":"1\u002falpha=%{x}\u003cbr\u003eTraining MSE=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":[100.0,79.24828983539173,62.80291441834253,49.770235643321115,39.442060594376564,31.25715849688235,24.770763559917114,19.630406500402703,15.556761439304722,12.32846739442066,9.770099572992251,7.74263682681127,6.1359072734131725,4.862601580065354,3.85352859371053,3.0538555088334154,2.4201282647943825,1.917910261672489,1.519911082952934,1.2045035402587825,0.9545484566618336,0.7564633275546291,0.5994842503189408,0.47508101621027987,0.3764935806792467,0.298364724028334,0.23644894126454072,0.18738174228603852,0.1484968262254465,0.1176811952434999,0.093260334688322,0.07390722033525783,0.058570208180566664,0.04641588833612777,0.03678379771828635,0.029150530628251757,0.023101297000831602,0.01830738280295368,0.014508287784959403,0.011497569953977356,0.009111627561154887,0.007220809018385471,0.00572236765935022,0.004534878508128583,0.0035938136638046254,0.0028480358684358047,0.0022570197196339213,0.001788649529057435,0.0014174741629268048,0.0011233240329780265,0.0008902150854450394,0.0007054802310718645,0.0005590810182512223,0.0004430621457583878,0.0003511191734215135,0.0002782559402207126,0.00022051307399030456,0.0001747528400007683,0.00013848863713938745,0.00010974987654930568,0.00008697490026177834,0.00006892612104349695,0.00005462277217684348,0.00004328761281083062,0.00003430469286314919,0.000027185882427329403,0.000021544346900318823,0.000017073526474706923,0.000013530477745798076,0.00001072267222010323,8.497534359086437e-6,6.734150657750828e-6,5.336699231206313e-6,4.229242874389499e-6,3.351602650938841e-6,2.6560877829466896e-6,2.104904144512022e-6,1.6681005372000591e-6,1.3219411484660286e-6,1.0476157527896663e-6,8.302175681319736e-7,6.579332246575682e-7,5.214008287999695e-7,4.132012400115335e-7,3.2745491628777317e-7,2.595024211399732e-7,2.0565123083486514e-7,1.6297508346206468e-7,1.2915496650148827e-7,1.0235310218990269e-7,8.11130830789689e-8,6.42807311728432e-8,5.094138014816385e-8,4.0370172585965494e-8,3.1992671377973846e-8,2.5353644939701163e-8,2.009233002565046e-8,1.592282793341094e-8,1.2618568830660186e-8,1e-8],"xaxis":"x","y":[17.010202260722366,17.010202261404533,17.01020226249063,17.01020226421978,17.010202266972637,17.010202271355062,17.01020227833134,17.010202289435938,17.010202307110365,17.01020233523851,17.010202379997317,17.010202451207427,17.01020256447656,17.010202744597336,17.010203030927883,17.010203485899755,17.01020420844624,17.010205355147413,17.010207173428793,17.010210053490702,17.01021460915298,17.010221802961002,17.010233138307797,17.010250951595367,17.010278850976118,17.010322364606786,17.01038987843079,17.01049395551312,17.010653123926886,17.010894177043458,17.011254917203086,17.01178705367378,17.01255861343561,17.01365476550344,17.015175533673478,17.017228772821046,17.019917418713767,17.023321693412004,17.02747946549424,17.032370335058665,17.037909677005427,17.04395667242461,17.050335669404152,17.056865156265626,17.063385790579808,17.069779618778675,17.075976181042414,17.081945772403238,17.087683957868336,17.093193495966876,17.098469778659382,17.103493934624016,17.108234620181484,17.112656490431597,17.116731639532087,17.12045043892705,17.123829721961737,17.12691814205784,17.129799870156 ...

# %% [markdown]
# ## Video 5: How Regularization Works (no code)

# %% [markdown]
# ## Video 6: Scaling

# %%
all_degree_3_combinations
# Out:
#      cylinders  displacement     hp  weight  acceleration  cylinders^2  \
# 0          8.0         307.0  130.0  3504.0          12.0         64.0
# 1          8.0         350.0  165.0  3693.0          11.5         64.0
# 2          8.0         318.0  150.0  3436.0          11.0         64.0
# 3          8.0         304.0  150.0  3433.0          12.0         64.0
# 4          8.0         302.0  140.0  3449.0          10.5         64.0
# ..         ...           ...    ...     ...           ...          ...
# 387        4.0         140.0   86.0  2790.0          15.6         16.0
# 388        4.0          97.0   52.0  2130.0          24.6         16.0
# 389        4.0         135.0   84.0  2295.0          11.6         16.0
# 390        4.0         120.0   79.0  2625.0          18.6         16.0
# 391        4.0         119.0   82.0  2720.0          19.4         16.0
#
#      cylinders displacement  cylinders hp  cylinders weight  \
# 0                    2456.0        1040.0           28032.0
# 1                    2800.0        1320.0           29544.0
# 2                    2544.0        1200.0           27488.0
# 3                    2432.0        1200.0           27464.0
# 4                    2416.0        1120.0           27592.0
# ..                      ...           ...               ...
# 387                   560.0         344.0           11160.0
# 388                   388.0         208.0            8520.0
# 389                   540.0         336.0            9180.0
# 390                   480.0         316.0           10500.0
# 391                   476.0         328.0           10880.0
#
#      cylinders acceleration  ...       hp^3  hp^2 weight  hp^2 acceleration  \
# 0                      96.0  ...  2197000.0   59217600.0           202800.0
# 1                      92.0  ...  4492125.0  100541925.0           313087.5
# 2                      88.0  ...  3375000.0   77310000.0           247500.0
# 3                      96.0  ...  3375000.0   77242500.0           270000.0
# 4                      84.0  ...  2744000.0   67600400.0           205800.0
# ..                      ...  ...        ...          ...                ...
# 387                    62.4  ...   636056.0   20634840.0           115377.6
# 388                    98.4  ...   140608.0    5759520.0            66518.4
# 389                    46.4  ...   592704.0   16193520.0            81849.6
# 390                    74.4  ...   493039.0   16382625.0           116082.6
# 391                    77.6  ...   551368.0   18289280.0           130445.6
#
#       hp weight^2  hp weight acceleration  hp acceleration^2      weight^3  \
# 0    1.596142e+09               5466240.0           18720.00  4.302217e+10
# 1    2.250311e+09               7007467.5           21821.25  5.036605e+10
# 2    1.770914e+09               5669400.0           18150.00  4.056575e+10
# 3    1.767823e+09               6179400.0           21600.00  4.045958e+10
# 4    1.665384e+09               5070030.0           15435.00  4.102793e+10
# ..            ...                     ...                ...           ...
# 387  6.694326e+08               3743064.0           20928.96  2.171764e+10
# 388  2.359188e+08               2724696.0           31468.32  9.663597e+09
# 389  4.424301e+08               2236248.0           11303.04  1.208782e+10
# 390  5.443594e+08               3857175.0           27330.84  1.808789e+10
# 391  6.066688e+08               4326976.0           30861.52  2.012365e+10
#
#      weight^2 acceleration  weight acceleration^2  acceleration^3
# 0              147336192.0              504576.00        1728.000
# 1              156839863.5              488399.25        1520.875
# 2              129867056.0              415756.00        1331.000
# 3              141425868.0              494352.00        1728.000
# 4              124903810.5              380252.25        1157.625
# ..                     ...                    ...             ...
# 387            121431960.0              678974.40        3796.416
# 388            111607740.0             1288990.80       14886.936
# 389             61097490.0              308815.20        1560.896
# 390            128165625.0              908145.00        6434.856
# 391            143528960.0             1023699.20        7301.384
#
# [392 rows x 55 columns]

# %%
ss = StandardScaler()
rescaled_df = pd.DataFrame(ss.fit_transform(all_degree_3_combinations),
                           columns = ss.get_feature_names_out())

# %%
rescaled_df
# Out:
#      cylinders  displacement        hp    weight  acceleration  cylinders^2  \
# 0     1.483947      1.077290  0.664133  0.620540     -1.285258     1.543439
# 1     1.483947      1.488732  1.574594  0.843334     -1.466724     1.543439
# 2     1.483947      1.182542  1.184397  0.540382     -1.648189     1.543439
# 3     1.483947      1.048584  1.184397  0.536845     -1.285258     1.543439
# 4     1.483947      1.029447  0.924265  0.555706     -1.829655     1.543439
# ..         ...           ...       ...       ...           ...          ...
# 387  -0.864014     -0.520637 -0.480448 -0.221125      0.021294    -0.834466
# 388  -0.864014     -0.932079 -1.364896 -0.999134      3.287676    -0.834466
# 389  -0.864014     -0.568479 -0.532474 -0.804632     -1.430430    -0.834466
# 390  -0.864014     -0.712005 -0.662540 -0.415627      1.110088    -0.834466
# 391  -0.864014     -0.721574 -0.584501 -0.303641      1.400433    -0.834466
#
#      cylinders displacement  cylinders hp  cylinders weight  \
# 0                  1.225979      0.985504          1.023186
# 1                  1.570844      1.653412          1.171347
# 2                  1.314200      1.367166          0.969880
# 3                  1.201918      1.367166          0.967528
# 4                  1.185878      1.176335          0.980071
# ..                      ...           ...               ...
# 387               -0.674794     -0.674723         -0.630102
# 388               -0.847227     -0.999135         -0.888796
# 389               -0.694844     -0.693806         -0.824123
# 390               -0.754995     -0.741514         -0.694776
# 391               -0.759005     -0.712889         -0.657539
#
#      cylinders acceleration  ...      hp^3  hp^2 weight  hp^2 acceleration  \
# 0                  0.609812  ...  0.253777     0.334709           0.255559
# 1                  0.426793  ...  1.348294     1.224887           1.261545
# 2                  0.243773  ...  0.815550     0.724442           0.663290
# 3                  0.609812  ...  0.815550     0.722988           0.868523
# 4                  0.060754  ...  0.514634     0.515285           0.282924
# ..                      ...  ...       ...          ...                ...
# 387               -0.927552  ... -0.490619    -0.496412          -0.541863
# 388                0.719624  ... -0.726892    -0.816845          -0.987532
# 389               -1.659631  ... -0.511293    -0.592083          -0.847689
# 390               -0.378493  ... -0.558822    -0.588010          -0.535433
# 391               -0.232078  ... -0.531005    -0.546938          -0.404421
#
#      hp weight^2  hp weight acceleration  hp acceleration^2  weight^3  \
# 0       0.375014                0.212022          -0.777902  0.352053
# 1       0.970575                0.803569          -0.305269  0.613777
# 2       0.534128                0.289998          -0.864771  0.264510
# 3       0.531314                0.485744          -0.338988  0.260727
# 4       0.438053                0.059951          -1.278539  0.280982
# ..           ...                     ...                ...       ...
# 387    -0.468670               -0.449359          -0.441255 -0.407205
# 388    -0.863344               -0.840224           1.164952 -0.836791
# 389    -0.675335               -1.027698          -1.908253 -0.750396
# 390    -0.582537               -0.405562           0.534397 -0.536563
# 391    -0.525810               -0.225245           1.072475 -0.464012
#
#      weight^2 acceleration  weight acceleration^2  acceleration^3
# 0                 0.065767              -0.781142       -1.063297
# 1                 0.196284              -0.841789       -1.155608
# 2                -0.174141              -1.114132       -1.240232
# 3                -0.015401              -0.819472       -1.063297
# 4                -0.242303              -1.247238       -1.317502
# ..                     ...                    ...             ...
# 387              -0.289983              -0.127314       -0.141444
# 388              -0.424902               2.159666        4.801385
# 389              -1.118573              -1.515059       -1.137772
# 390              -0.197507               0.731857        1.034458
# 391               0.013482               1.165076        1.420652
#
# [392 rows x 55 columns]

# %%
np.mean(rescaled_df)
# Out:
# 2.1092177684900933e-16

# %%
np.var(rescaled_df)
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3785: FutureWarning:
#
# The behavior of DataFrame.var with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
# cylinders                              1.0
# displacement                           1.0
# hp                                     1.0
# weight                                 1.0
# acceleration                           1.0
# cylinders^2                            1.0
# cylinders displacement                 1.0
# cylinders hp                           1.0
# cylinders weight                       1.0
# cylinders acceleration                 1.0
# displacement^2                         1.0
# displacement hp                        1.0
# displacement weight                    1.0
# displacement acceleration              1.0
# hp^2                                   1.0
# hp weight                              1.0
# hp acceleration                        1.0
# weight^2                               1.0
# weight acceleration                    1.0
# acceleration^2                         1.0
# cylinders^3                            1.0
# cylinders^2 displacement               1.0
# cylinders^2 hp                         1.0
# cylinders^2 weight                     1.0
# cylinders^2 acceleration               1.0
# cylinders displacement^2               1.0
# cylinders displacement hp              1.0
# cylinders displacement weight          1.0
# cylinders displacement acceleration    1.0
# cylinders hp^2                         1.0
# cylinders hp weight                    1.0
# cylinders hp acceleration              1.0
# cylinders weight^2                     1.0
# cylinders weight acceleration          1.0
# cylinders acceleration^2               1.0
# displacement^3                         1.0
# displacement^2 hp                      1.0
# displacement^2 weight                  1.0
# displacement^2 acceleration            1.0
# displacement hp^2                      1.0
# displacement hp weight                 1.0
# displacement hp acceleration           1.0
# displacement weight^2                  1.0
# displacement weight acceleration       1.0
# displacement acceleration^2            1.0
# hp^3                                   1.0
# hp^2 weight                            1.0
# hp^2 acceleration                      1.0
# hp weight^2                            1.0
# hp weight acceleration                 1.0
# hp acceleration^2                      1.0
# weight^3                               1.0
# weight^2 acceleration                  1.0
# weight acceleration^2                  1.0
# acceleration^3                         1.0
# dtype: float64

# %%
pd.DataFrame(ss.inverse_transform(rescaled_df),
             columns = ss.get_feature_names_out())
# Out:
#      cylinders  displacement     hp  weight  acceleration  cylinders^2  \
# 0          8.0         307.0  130.0  3504.0          12.0         64.0
# 1          8.0         350.0  165.0  3693.0          11.5         64.0
# 2          8.0         318.0  150.0  3436.0          11.0         64.0
# 3          8.0         304.0  150.0  3433.0          12.0         64.0
# 4          8.0         302.0  140.0  3449.0          10.5         64.0
# ..         ...           ...    ...     ...           ...          ...
# 387        4.0         140.0   86.0  2790.0          15.6         16.0
# 388        4.0          97.0   52.0  2130.0          24.6         16.0
# 389        4.0         135.0   84.0  2295.0          11.6         16.0
# 390        4.0         120.0   79.0  2625.0          18.6         16.0
# 391        4.0         119.0   82.0  2720.0          19.4         16.0
#
#      cylinders displacement  cylinders hp  cylinders weight  \
# 0                    2456.0        1040.0           28032.0
# 1                    2800.0        1320.0           29544.0
# 2                    2544.0        1200.0           27488.0
# 3                    2432.0        1200.0           27464.0
# 4                    2416.0        1120.0           27592.0
# ..                      ...           ...               ...
# 387                   560.0         344.0           11160.0
# 388                   388.0         208.0            8520.0
# 389                   540.0         336.0            9180.0
# 390                   480.0         316.0           10500.0
# 391                   476.0         328.0           10880.0
#
#      cylinders acceleration  ...       hp^3  hp^2 weight  hp^2 acceleration  \
# 0                      96.0  ...  2197000.0   59217600.0           202800.0
# 1                      92.0  ...  4492125.0  100541925.0           313087.5
# 2                      88.0  ...  3375000.0   77310000.0           247500.0
# 3                      96.0  ...  3375000.0   77242500.0           270000.0
# 4                      84.0  ...  2744000.0   67600400.0           205800.0
# ..                      ...  ...        ...          ...                ...
# 387                    62.4  ...   636056.0   20634840.0           115377.6
# 388                    98.4  ...   140608.0    5759520.0            66518.4
# 389                    46.4  ...   592704.0   16193520.0            81849.6
# 390                    74.4  ...   493039.0   16382625.0           116082.6
# 391                    77.6  ...   551368.0   18289280.0           130445.6
#
#       hp weight^2  hp weight acceleration  hp acceleration^2      weight^3  \
# 0    1.596142e+09               5466240.0           18720.00  4.302217e+10
# 1    2.250311e+09               7007467.5           21821.25  5.036605e+10
# 2    1.770914e+09               5669400.0           18150.00  4.056575e+10
# 3    1.767823e+09               6179400.0           21600.00  4.045958e+10
# 4    1.665384e+09               5070030.0           15435.00  4.102793e+10
# ..            ...                     ...                ...           ...
# 387  6.694326e+08               3743064.0           20928.96  2.171764e+10
# 388  2.359188e+08               2724696.0           31468.32  9.663597e+09
# 389  4.424301e+08               2236248.0           11303.04  1.208782e+10
# 390  5.443594e+08               3857175.0           27330.84  1.808789e+10
# 391  6.066688e+08               4326976.0           30861.52  2.012365e+10
#
#      weight^2 acceleration  weight acceleration^2  acceleration^3
# 0              147336192.0              504576.00        1728.000
# 1              156839863.5              488399.25        1520.875
# 2              129867056.0              415756.00        1331.000
# 3              141425868.0              494352.00        1728.000
# 4              124903810.5              380252.25        1157.625
# ..                     ...                    ...             ...
# 387            121431960.0              678974.40        3796.416
# 388            111607740.0             1288990.80       14886.936
# 389             61097490.0              308815.20        1560.896
# 390            128165625.0              908145.00        6434.856
# 391            143528960.0             1023699.20        7301.384
#
# [392 rows x 55 columns]

# %%
scaled_ridge_model = Pipeline([
    ('josh_transform', PolynomialFeatures(degree = 3, include_bias = False)),
    ('scale', StandardScaler()),
    ('josh_regression', Ridge(alpha = 1))
])
scaled_ridge_model.fit(training_vehicle_data[numeric_features], training_vehicle_data["mpg"])
# Out:
# Pipeline(steps=[('josh_transform',
#                  PolynomialFeatures(degree=3, include_bias=False)),
#                 ('scale', StandardScaler()),
#                 ('josh_regression', Ridge(alpha=1))])

# %% [markdown]
# ## Video 7: GridSearchCV

# %%
scaled_ridge_model = Pipeline([
    ('josh_transform', PolynomialFeatures(degree = 3, include_bias = False)),
    ('scale', StandardScaler()),
    ('josh_regression', Ridge(alpha = 1))
])
scaled_ridge_model.fit(training_vehicle_data[numeric_features], training_vehicle_data["mpg"])
# Out:
# Pipeline(steps=[('josh_transform',
#                  PolynomialFeatures(degree=3, include_bias=False)),
#                 ('scale', StandardScaler()),
#                 ('josh_regression', Ridge(alpha=1))])

# %%
def get_training_and_dev_MSE_for_model_with_alpha(alpha, training, dev):
    scaled_ridge_model = Pipeline([
        ('josh_transform', PolynomialFeatures(degree = 3, include_bias = False)),
        ('scale', StandardScaler()),
        ('josh_regression', Ridge(alpha = alpha))
    ])
    scaled_ridge_model.fit(training[numeric_features], training["mpg"])
    training_error = mean_squared_error(scaled_ridge_model.predict(training[numeric_features]), training["mpg"])
    validation_error = mean_squared_error(scaled_ridge_model.predict(dev[numeric_features]), dev["mpg"])
    return alpha, training_error, validation_error

# %%
get_training_and_dev_MSE_for_model_with_alpha(10, training_vehicle_data, dev_vehicle_data)
# Out:
# (10, 14.424024606452516, 15.637901365900639)

# %%
results = [get_training_and_dev_MSE_for_model_with_alpha(alpha, training_vehicle_data, dev_vehicle_data) \
             for alpha in 10**np.linspace(-5, 4, 100)]
results = pd.DataFrame(results, columns = ["alpha", "Training MSE", "Dev MSE"])

# %%
results["1/alpha"] = 1.0/results["alpha"]

fig = px.line(results, x = "1/alpha", y = ["Training MSE", "Dev MSE"], log_x = True)
fig.write_image("MSE_vs_1_over_alpha_for_regularized_55_parameter_model.png", scale = 3)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e5438b02-023c-4beb-a2e2-f7a44cecfab4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e5438b02-023c-4beb-a2e2-f7a44cecfab4")) {                    Plotly.newPlot(                        "e5438b02-023c-4beb-a2e2-f7a44cecfab4",                        [{"hovertemplate":"variable=Training MSE\u003cbr\u003e1\u002falpha=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Training MSE","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Training MSE","orientation":"v","showlegend":true,"x":[99999.99999999999,81113.08307896873,65793.32246575682,53366.99231206313,43287.612810830615,35111.917342151275,28480.35868435805,23101.29700083158,18738.17422860383,15199.11082952933,12328.467394420659,10000.0,8111.308307896872,6579.332246575683,5336.699231206313,4328.761281083057,3511.1917342151305,2848.035868435802,2310.1297000831582,1873.8174228603832,1519.9110829529332,1232.8467394420659,1000.0,811.1308307896873,657.9332246575682,533.6699231206306,432.8761281083057,351.1191734215131,284.8035868435802,231.01297000831602,187.3817422860383,151.99110829529332,123.28467394420659,100.0,81.11308307896873,65.79332246575676,53.366992312063076,43.287612810830566,35.11191734215131,28.480358684358023,23.101297000831583,18.738174228603828,15.199110829529332,12.32846739442066,10.0,8.111308307896874,6.5793322465756825,5.336699231206313,4.328761281083062,3.5111917342151275,2.848035868435799,2.310129700083158,1.8738174228603832,1.5199110829529332,1.232846739442066,1.0,0.8111308307896873,0.6579332246575682,0.5336699231206312,0.4328761281083052,0.3511191734215127,0.28480358684357987,0.2310129700083158,0.1873817422860383,0.1519911082952933,0.1232846739442066,0.1,0.08111308307896872,0.06579332246575682,0.05336699231206312,0.043287612810830524,0.03511191734215127,0.02848035868435799,0.02310129700083158,0.01873817422860383,0.01519911082952933,0.012328467394420659,0.01,0.008111308307896872,0.006579332246575682,0.005336699231206302,0.004328761281083053,0.0035111917342151274,0.002848035868435799,0.0023101297000831583,0.0018738174228603833,0.0015199110829529332,0.0012328467394420659,0.001,0.0008111308307896856,0.0006579332246575682,0.0005336699231206301,0.00043287612810830614,0.00035111917342151277,0.0002848035868435805,0.0002310129700083158,0.00018738174228603868,0.0001519911082952933,0.00012328467394420633,0.0001],"xaxis":"x","y":[10.161072970846055,10.164085967007798,10.1678410483488,10.17245873890953,10.17806638009767,10.184794509003344,10.192770536976557,10.202110094088301,10.2129078322364,10.2252307862074,10.239117901740673,10.254588613091176,10.271661326979611,10.290379774252187,10.310842238242207,10.333226610884102,10.357803772094536,10.384933153013218,10.415037348461107,10.448556897719646,10.48589139933056,10.527338138920358,10.57304292588984,10.622977855024285,10.676955734010642,10.73468134552574,10.79582862343491,10.86012490131392,10.927422349784926,10.997742800821024,11.071291775559269,11.148445450467802,11.229716902357733,11.31570546305573,11.407029057327142,11.504238538308309,11.607717520715745,11.717579360253433,11.833580158013781,11.955068466252365,12.080987030884707,12.209931205196636,12.340256396232892,12.470216794670048,12.598112177564598,12.722419763973148,12.841893463049129,12.955621445154168,13.063041927096583,13.163923813623295,13.25832227301957,13.346520058434354,13.428964866234248,13.506212284925818,13.578882903481087,13.647640116809578,13.71319141047035,13.77631066308634,13.837873540513774,13.898894029762932,13.960548765803377,14.024177401899113,14.091251691483947,14.163312836017331,14.241885162931743,14.32838215122726,14.424024606452516,14.52978718130002,14.64637 ...

# %%
results
# Out:
#            alpha  Training MSE    Dev MSE        1/alpha
# 0       0.000010     10.161073  18.088539  100000.000000
# 1       0.000012     10.164086  18.067380   81113.083079
# 2       0.000015     10.167841  18.042118   65793.322466
# 3       0.000019     10.172459  18.012132   53366.992312
# 4       0.000023     10.178066  17.976840   43287.612811
# ..           ...           ...        ...            ...
# 95   4328.761281     21.999616  28.890391       0.000231
# 96   5336.699231     22.866702  30.072831       0.000187
# 97   6579.332247     23.935122  31.491170       0.000152
# 98   8111.308308     25.230633  33.172013       0.000123
# 99  10000.000000     26.767494  35.127665       0.000100
#
# [100 rows x 4 columns]

# %%
results.sort_values("Dev MSE").iloc[0, :]
# Out:
# alpha            0.187382
# Training MSE    12.955621
# Dev MSE         14.919360
# 1/alpha          5.336699
# Name: 47, dtype: float64

# %%
scaled_ridge_model = Pipeline([
    ('josh_transform', PolynomialFeatures(degree = 3, include_bias = False)),
    ('scale', StandardScaler()),
    ('josh_regression', Ridge())
])

parameters_to_try = {'josh_regression__alpha': 10**np.linspace(-5, 4, 100)}

from sklearn.model_selection import GridSearchCV
model_finder = GridSearchCV(estimator = scaled_ridge_model,
                               param_grid = parameters_to_try,
                               scoring = "neg_mean_squared_error",
                               cv=[[training_indices, dev_indices]])

# %%
model_finder.fit(vehicle_data[numeric_features], vehicle_data["mpg"])
# Out:
# GridSearchCV(cv=[[array([145, 390, 224,  59,  55, 229, 341, 140, 273, 311, 128,  36, 214,
#        369, 263, 313, 158, 233,  71, 148, 213, 185, 156, 354, 312,   0,
#        372,  45, 240, 391, 247, 320, 331, 359, 243, 256,  94, 261, 125,
#        114, 365, 167, 235, 193, 286,  93,  54, 241, 321, 111,  79, 303,
#         82, 228,  37, 131, 246, 178, 370, 309, 144, 382,  13, 376, 310,
#         42, 157, 348, 319, 336, 342, 116, 216, 267, 237, 149, 386, 196,
#        101, 207, 262, 297, 155,  80,  95,   8,...
#        8.11130831e+01, 1.00000000e+02, 1.23284674e+02, 1.51991108e+02,
#        1.87381742e+02, 2.31012970e+02, 2.84803587e+02, 3.51119173e+02,
#        4.32876128e+02, 5.33669923e+02, 6.57933225e+02, 8.11130831e+02,
#        1.00000000e+03, 1.23284674e+03, 1.51991108e+03, 1.87381742e+03,
#        2.31012970e+03, 2.84803587e+03, 3.51119173e+03, 4.32876128e+03,
#        5.33669923e+03, 6.57933225e+03, 8.11130831e+03, 1.00000000e+04])},
#              scoring='neg_mean_squared_error')

# %%
best_model = model_finder.best_estimator_
best_model
# Out:
# Pipeline(steps=[('josh_transform',
#                  PolynomialFeatures(degree=3, include_bias=False)),
#                 ('scale', StandardScaler()),
#                 ('josh_regression', Ridge(alpha=0.1873817422860383))])

# %%
print(f"Dev MSE for our best Ridge Regression model: {-model_finder.best_score_}") #e4
# Out:
# Dev MSE for our best Ridge Regression model: 14.919359682999515

# %%
mean_squared_error(best_model.predict(training_vehicle_data[numeric_features]), training_vehicle_data["mpg"])
# Out:
# 13.117880075653806

# %%
best_model.named_steps["josh_regression"].coef_
# Out:
# array([-0.73530146,  1.75813672, -2.46936302, -2.25615871, -0.43855591,
#        -5.8966427 , -8.78224878,  4.71180015, -1.67507671, -3.1155934 ,
#        -6.52792997,  5.89534164,  0.09106638, -2.63718664,  0.19428043,
#         0.80252557, -5.06081536, -2.96912185,  1.06313392, -0.90177626,
#         0.9576364 , -1.31198808, -0.10363051,  1.62934063,  3.82843492,
#         0.65387865, -3.94457103, -0.06559292,  1.55403677,  0.77701981,
#         2.75919058,  6.64525538,  0.82720006,  0.68679851,  1.69426684,
#         3.61354074, -5.78649891,  0.41620389,  6.60086005, -1.23490938,
#         2.2620615 , 10.84849258,  1.4014152 ,  1.12620482, -7.35774836,
#         0.71444529,  0.36462511, -6.947313  ,  1.25991107, -2.11921906,
#        -0.38827504, -1.80387919, -4.41125974,  7.46613999, -0.3811871 ])

# %%
pd.DataFrame([best_model.named_steps["josh_regression"].coef_],
             columns = best_model.named_steps["josh_transform"].get_feature_names_out())
# Out:
#    cylinders  displacement        hp    weight  acceleration  cylinders^2  \
# 0  -0.735301      1.758137 -2.469363 -2.256159     -0.438556    -5.896643
#
#    cylinders displacement  cylinders hp  cylinders weight  \
# 0               -8.782249        4.7118         -1.675077
#
#    cylinders acceleration  ...      hp^3  hp^2 weight  hp^2 acceleration  \
# 0               -3.115593  ...  0.714445     0.364625          -6.947313
#
#    hp weight^2  hp weight acceleration  hp acceleration^2  weight^3  \
# 0     1.259911               -2.119219          -0.388275 -1.803879
#
#    weight^2 acceleration  weight acceleration^2  acceleration^3
# 0               -4.41126                7.46614       -0.381187
#
# [1 rows x 55 columns]

# %%
scaled_ridge_model = Pipeline([
    ('josh_transform', PolynomialFeatures(degree = 3, include_bias = False)),
    ('scale', StandardScaler()),
    ('josh_regression', Ridge())
])

parameters_to_try = {'josh_regression__alpha': [0.001, 1, 1000]}

from sklearn.model_selection import GridSearchCV
model_finder = GridSearchCV(estimator = scaled_ridge_model,
                               param_grid = parameters_to_try,
                               scoring = "neg_mean_squared_error",
                               cv=[[training_indices, dev_indices]])

model_finder.fit(vehicle_data[numeric_features], vehicle_data["mpg"])
model_finder.cv_results_
# Out:
# {'mean_fit_time': array([0.0095613 , 0.00885034, 0.00758672]),
#  'std_fit_time': array([0., 0., 0.]),
#  'mean_score_time': array([0.00329328, 0.0031383 , 0.00617647]),
#  'std_score_time': array([0., 0., 0.]),
#  'param_josh_regression__alpha': masked_array(data=[0.001, 1.0, 1000.0],
#               mask=[False, False, False],
#         fill_value=1e+20),
#  'params': [{'josh_regression__alpha': 0.001},
#   {'josh_regression__alpha': 1},
#   {'josh_regression__alpha': 1000}],
#  'split0_test_score': array([-16.37659428, -15.06212874, -24.20924068]),
#  'mean_test_score': array([-16.37659428, -15.06212874, -24.20924068]),
#  'std_test_score': array([0., 0., 0.]),
#  'rank_test_score': array([2, 1, 3], dtype=int32)}

# %%
scaled_ridge_model = Pipeline([
    ('josh_transform', PolynomialFeatures(degree = 3, include_bias = False)),
    ('scale', StandardScaler()),
    ('josh_regression', Ridge())
])
vhd_shuffled = shuffle(vehicle_data.copy())

parameters_to_try = {'josh_regression__alpha': [0.001, 1, 1000]}

from sklearn.model_selection import GridSearchCV
model_finder = GridSearchCV(estimator = scaled_ridge_model,
                               param_grid = parameters_to_try,
                               scoring = "neg_mean_squared_error",
                               cv=len(vhd_shuffled))

model_finder.fit(vhd_shuffled[numeric_features], vhd_shuffled["mpg"])
model_finder.cv_results_
# Out:
# {'mean_fit_time': array([0.01614952, 0.02755315, 0.01275449]),
#  'std_fit_time': array([0.01546922, 0.01538167, 0.00683765]),
#  'mean_score_time': array([0.00481343, 0.00730493, 0.00356616]),
#  'std_score_time': array([0.0047313 , 0.00579241, 0.0015338 ]),
#  'param_josh_regression__alpha': masked_array(data=[0.001, 1.0, 1000.0],
#               mask=[False, False, False],
#         fill_value=1e+20),
#  'params': [{'josh_regression__alpha': 0.001},
#   {'josh_regression__alpha': 1},
#   {'josh_regression__alpha': 1000}],
#  'split0_test_score': array([-7.30262227, -3.28574471, -6.18145941]),
#  'split1_test_score': array([-5.92595161, -0.36275215, -0.02292337]),
#  'split2_test_score': array([-0.3818171 , -0.64345717, -0.03742495]),
#  'split3_test_score': array([-27.57295791,  -7.25582059, -24.49467345]),
#  'split4_test_score': array([-41.83213724, -32.94134559, -31.8728667 ]),
#  'split5_test_score': array([-67.01211045,  -1.75862386,  -5.98732606]),
#  'split6_test_score': array([-1.69927733, -2.73172956, -6.65646856]),
#  'split7_test_score': array([-0.04234093, -0.01597   , -4.37207795]),
#  'split8_test_score': array([-184.9803571 , -208.26911445, -301.50989825]),
#  'split9_test_score': array([-3.46323322, -3.16399022, -5.51961331]),
#  'split10_test_score': array([ -3.76516449,  -6.4192792 , -15.23650891]),
#  'split11_test_score': array([ -5.07526357, -11.36070667, -10.23716077]),
#  'split12_test_score': array([-12.02649123, -15.7411685 , -12.61692278]),
#  'split13_test_score': array([-0.03941712, -0.00608106, -0.21880454]),
#  'split14_test_score': array([-4.7375349 , -7.1822694 , -0.13047053]),
#  'split15_test_score': array([-0.00846197, -0.8771262 , -0.22442393]),
#  'split16_test_score': array([-1.18162404, -0.29625853, -0.485547  ]),
#  'split17_test_score': array([ -1.39738842,  -1.2197401 , -17.98322492]),
#  'split18_test_score': array([-1.60101649, -0.21610659, -4.04421225]),
#  'split19_test_score': array([-2.49140084, -4.72603315, -5.62318439]),
#  'split20_test_score': array([-1.02938779, -0.01178306, -7.4771058 ]),
#  'split21_test_score': array([-11.43770296, -17.00218669, -63.2250065 ]),
#  'split22_test_score': array([  -7.61174301, -100.5202506 ,  -98.91330766]),
#  'split23_test_score': array([-27.03905552, -20.70255903, -24.09763078]),
#  'split24_test_score': array([ -7.15324224, -12.27834058, -35.48268821]),
#  'split25_test_score': array([-14.08196749, -11.68457476,  -1.69958376]),
#  'split26_test_score': array([-17.73330345, -20.44325881,  -7.31325821]),
#  'split27_test_score': array([-3.63599026, -1.68695638, -1.5601941 ]),
#  'split28_test_score': array([-7.99942186, -5.6503635 , -7.45146737]),
#  'split29_test_score': array([ -0.04783364,  -0.24446368, -23.88580571]),
#  'split30_test_score': array([ -5.26059489, -13.4883726 , -29.59687718]),
#  'split31_test_score': array([-29.84803328, -21.56004065,  -7.61601052]),
#  'split32_test_score': array([ -3.70636518,  -4.20156048, -11.69353754]),
#  'split33_test_score': array([-3.80005665, -0.55672862, -0.25927718]),
#  'split34_test_score': array([-5.94299822, -7.29553114, -1.68622384]),
#  'split35_test_score': array([-13.67230351, -18.34745994, -58.73084933]),
#  'split36_test_score': array([-4.52289672, -0.34589385, -1.20789728]),
#  'split37_test_score': array([-11.01819866, -31.61153137,  -7.93600583]),
#  'split38_test_score': array([-1.77796356, -0.0593522 , -0.51297205]),
#  'split39_test_score': array([ -89.74618794,  -85.0378968 , -207.94292075]),
#  'split40_test_score': array([-14.16749395,  -0.07791754,  -0.01619592]),
#  'split41_test_score': array([-4.84800265, -4.11454082, -0.63484889]),
#  'split42_test_score': array([-0.13532278, -0.53513272, -7.4786004 ]),
#  'split43_test_score': array([ -0.96867416,  -4.84194304, -19.45331234]),
#  'split44_test_score': array([ -0.03739849,  -1.19296359, -10.02297763]),
#  'split45_test_score': array([-16.40581154, -11.63976299, -24.6299655 ]),
#  'split46_test_score': array([-2.44137174, -6.55463179, -2.75177556]),
#  'split47_test_score': array([-0.01455873, -1.67267075, -5.53516505]),
#  'split48_test_score': array([-6.09424973, -1.58582977, -0.75780657]),
#  'split49_test_score': array([-4.09961978, -0.26140792, -4.3084271 ]),
#  'split50_test_score': array([-58.14543338, -65.55762008, -61.22127826]),
#  'split51_test_score': array([-21.53320468, -48.33123504, -37.54681219]),
#  'split52_test_score': array([-12.18716165, -12.07325916, -12.31840356]),
#  'split53_test_score': array([ -5.84386644,  -9.49155436, -24.85594712]),
#  'split54_test_score': array([  -1.88414753, -155.67236297, -141.11638624]),
#  'split55_test_score': array([-24.70938535, -27.30397278, -50.02924493]),
#  'split56_test_score': array([-28.00216601, -31.83172209, -73.33070804]),
#  'split57_test_score': array([ -1.58832654,  -4.41924149, -29.77680569]),
#  'split58_test_score': array([-1.97918817, -0.68694903, -0.06362564]),
#  'split59_test_score': array([ -4.15928175,  -5.23696051, -12.9767804 ]),
#  'split60_test_score': array([-16.04515591,  -9.91799714, -18.75482804]),
#  'split61_test_score': array([-1.11355819, -0.87938038, -4.16963595]),
#  'split62_test_score': array([-0.88531026, -0.89354792, -1.20478657]),
#  'split63_test_score': array([-9.02717793, -0.40922816, -2.31627424]),
#  'split64_test_score': array([-0.85978642, -0.50097687, -0.19357711]),
#  'split65_test_score': array([-5.19081599, -0.05779121, -1.99111876]),
#  'split66_test_score': array([ -1.05609455,  -3.43157431, -10.76464545]),
#  'split67_test_score': array([-1.56635113, -1.44036806, -2.65564335]),
#  'split68_test_score': array([ -4.90272434,  -7.77160717, -11.82393466]),
#  'split69_test_score': array([ -0.19758954,  -0.08601357, -10.20077182]),
#  'split70_test_score': array([-0.38064026, -0.65683986, -3.52562869]),
#  'split71_test_score': array([-125.5420303 , -122.42297652, -219.5895438 ]),
#  'split72_test_score': array([-30.71404443, -18.79961974, -36.68892361]),
#  'split73_test_score': array([-0.76297578, -0.08841605, -5.79113248]),
#  'split74_test_score': array([-0.03132358, -1.56773327, -0.06925538]),
#  'split75_test_score': array([-5.06670243, -9.85810442, -0.99836659]),
#  'split76_test_score': array([-25.26907292, -26.10564768, -71.42612826]),
#  'split77_test_score': array([-1.66165579e-02, -9.53898396e+00, -4.35804483e+01]),
#  'split78_test_score': array([-4.84109887e-01, -3.24354471e-04, -1.55760435e+00]),
#  'split79_test_score': array([-2.5287373 , -2.09980751, -0.03422788]),
#  'split80_test_score': array([-0.35613645, -0.29678965, -0.00627237]),
#  'split81_test_score': array([-51.26230483, -51.91397231, -25.84018964]),
#  'split82_test_score': array([-10.35262704, -60.41650983, -44.26372889]),
#  'split83_test_score': array([-1.35323838, -0.50752219, -5.91476911]),
#  'split84_test_score': array([ -34.98748887, -100.08942687,  -20.51229592]),
#  'split85_test_score': array([-13.09234461,  -5.38501703, -24.88527667]),
#  'split86_test_score': array([-32.78981129, -32.72653684, -60.99008699]),
#  'split87_test_score': array([ -4.43846426,  -7.07805302, -30.13335102]),
#  'split88_test_score': array([-0.16155641, -0.00097636, -0.94582261]),
#  'split89_test_score': array([ -0.18812837,  -3.51029977, -13.93759762]),
#  'split90_test_score': array([-0.08957823, -0.49147485, -2.87353939]),
#  'split91_test_score': array([-0.16236293, -2.21550675, -9.744468  ]),
#  'split92_test_score': array([-1.96467067, -3.11115229, -0.15823846]),
#  'split93_test_score': array([-0.07256892, -0.07545762, -1.08584429]),
#  'split94_test_score': array([ -4.97743592, -19.16530046, -15.91465604]),
#  'split95_test_score': array([ -4.27248721,  -9.29673266, -13.9042739 ]),
#  'split96_test_score': array([-27.59576843, -23.94655931, -32.15990211]),
#  'split97_test_score': array([-42.16029969, -34.61999592, -21.96465887]),
#  'split98_test_score': array([ -22.73425252,  -66.03058925, -197.71262469]),
#  'split99_test_score': array([-13.44061135, -20.86787867, -37.92225719]),
#  'split100_test_score': array([ -0.16369689, -10.2839705 ,  -7.85950013]),
#  'split101_test_score': array([-0.44785858, -0.49169033, -4.32479184]),
#  'split102_test_score': array([ -0.28664289,  -0.83563317, -27.17815675]),
#  'split103_test_score': array([-12.10624484, -18.12596858,  -4.7048433 ]),
#  'split104_test_score': array([-14.71970772,  -9.24093701, -11.32601152]),
#  'split105_test_score': array([-12.59527355, -10.59035724,  -5.54501405]),
#  'split106_test_score': array([-6.24159144, -3.78694028, -1.17802064]),
#  'split107_test_score': array([-1.33944889, -4.37977457, -7.76356505]),
#  'split108_test_score': array([ -0.93611369,  -5.74342483, -46.05578097]),
#  'split109_test_score': array([-45.40585019, -31.87801371, -28.14587264]),
#  'split110_test_score': array([-0.17561809, -3.15493307, -0.10047655]),
#  'split111_test_score': array([ -1.33271599,  -2.7474859 , -16.4625203 ]),
#  'split112_test_score': array([-0.45216601, -2.19369861, -7.01211029]),
#  'split113_test_score': array([-1.64338821, -1.358414  , -5.11500524]),
#  'split114_test_score': array([-0.34177537, -0.05306106, -0.17399179]),
#  'split115_test_score': array([ -4.67326546,  -6.83106491, -24.69979799]),
#  'split116_test_score': array([-24.6056686 , -47.5851358 , -26.15532466]),
#  'split117_test_score': array([-3.54125831, -0.03389517, -5.05514572]),
#  'split118_test_score': array([-10.15123731,  -3.2024963 ,  -9.55402976]),
#  'split119_test_score': array([-4.88027344, -2.38836508, -0.85321532]),
#  'split120_test_score': array([ -2.23500825,  -3.19529443, -21.64737869]),
#  'split121_test_score': array([-4.77670543, -5.48490074, -6.0095291 ]),
#  'split122_test_score': array([ -2.70680412,  -2.55420901, -16.55891853]),
#  'split123_test_score': array([-6.46183194, -7.07482343, -5.24115521]),
#  'split124_test_score': array([-5.42956625, -5.57883505, -9.0770771 ]),
#  'split125_test_score': array([-10.17615606, -12.17163604, -19.29950195]),
#  'split126_test_score': array([ -4.12386336,  -2.09480563, -15.24763703]),
#  'split127_test_score': array([-2.51375476, -2.45076025, -1.26179278]),
#  'split128_test_score': array([-0.16186959, -1.01743242, -3.81973186]),
#  'split129_test_score': array([-1.40379807, -0.38498487, -0.06230986]),
#  'split130_test_score': array([-4.72694794, -4.05912584, -1.16796238]),
#  'split131_test_score': array([-0.20595401, -0.45432949, -4.58477032]),
#  'split132_test_score': array([-6.37761962, -0.8345778 , -0.47587729]),
#  'split133_test_score': array([ -8.37601239,  -8.67101516, -25.63999145]),
#  'split134_test_score': array([-14.93166312, -22.24182135, -66.95809627]),
#  'split135_test_score': array([-11.74120814,  -7.0959126 ,  -0.58286325]),
#  'split136_test_score': array([-20.43409998, -19.30280028, -31.84595959]),
#  'split137_test_score': array([ -0.84444779,  -4.32690157, -12.25562852]),
#  'split138_test_score': array([ -51.79106271, -101.14191857,  -18.90795545]),
#  'split139_test_score': array([ -2.54112788,  -4.26982114, -13.38803713]),
#  'split140_test_score': array([-10.26938431,  -5.50481143, -16.23281346]),
#  'split141_test_score': array([ -3.17570185,  -6.37965228, -20.50642952]),
#  'split142_test_score': array([-4.79972951, -1.50745863, -5.48779836]),
#  'split143_test_score': array([-3.45594512, -0.62600081, -0.87114711]),
#  'split144_test_score': array([-12.08583754,  -3.33082324,  -0.08441279]),
#  'split145_test_score': array([-11.12569475, -10.86251223, -24.47299623]),
#  'split146_test_score': array([-47.8087369 , -40.43166619, -15.69789599]),
#  'split147_test_score': array([-2.02822774, -4.38610151, -2.23582495]),
#  'split148_test_score': array([-0.04768994, -0.04171696, -0.54681236]),
#  'split149_test_score': array([-6.20384262, -6.54423837, -0.28181262]),
#  'split150_test_score': array([ -9.49299051,  -2.87771174, -17.46505877]),
#  'split151_test_score': array([-0.16515016, -0.07022285, -0.17283471]),
#  'split152_test_score': array([-6.27164339, -7.4649125 , -0.02384426]),
#  'split153_test_score': array([ -6.15394456, -15.82001047,  -3.26255756]),
#  'split154_test_score': array([ -97.25708072,  -64.7632459 , -169.64221146]),
#  'split155_test_score': array([-104.98263361,  -26.15025998,  -34.91096079]),
#  'split156_test_score': array([-31.85518777, -45.97605267, -71.92132536]),
#  'split157_test_score': array([-5.00183454, -4.63842234, -0.04771091]),
#  'split158_test_score': array([-2.16650328, -4.06818107, -2.38759611]),
#  'split159_test_score': array([-27.25934419, -10.00663364,  -2.81191521]),
#  'split160_test_score': array([-12.8253968 , -20.09308172,  -8.67360581]),
#  'split161_test_score': array([-1.53144000e-02, -3.26495355e-01, -1.92598940e+01]),
#  'split162_test_score': array([-109.53822876, -112.64794473,  -90.38855214]),
#  'split163_test_score': array([-0.36616172, -0.24033736, -0.0695924 ]),
#  'split164_test_score': array([ -5.52496561,  -2.93040371, -13.58662834]),
#  'split165_test_score': array([ -0.2124835 ,  -0.83250072, -11.15903583]),
#  'split166_test_score': array([-14.98012597, -12.08264053,  -4.75458694]),
#  'split167_test_score': array([ -1.80057315,  -4.79728126, -19.59764341]),
#  'split168_test_score': array([-0.60594291, -0.58709813, -0.76242047]),
#  'split169_test_score': array([ -82.51629027, -167.76977612, -132.48434901]),
#  'split170_test_score': array([ -9.85568972,  -7.85785652, -27.05057686]),
#  'split171_test_score': array([-486.46050691, -335.77520111, -236.53630515]),
#  'split172_test_score': array([ -0.16475389,  -0.15331818, -12.77532535]),
#  'split173_test_score': array([-8.01787302, -8.48025652, -0.07133417]),
#  'split174_test_score': array([ -5.61938641,  -8.79710483, -29.59720653]),
#  'split175_test_score': array([-0.47017221, -0.10704866, -0.03508291]),
#  'split176_test_score': array([-5.47520374, -7.83560983, -9.86825782]),
#  'split177_test_score': array([-4.35282741, -0.39244207, -6.95193772]),
#  'split178_test_score': array([-1.86691545, -0.06701547, -0.73533851]),
#  'split179_test_score': array([-19.00196755, -16.92400542,  -0.42278211]),
#  'split180_test_score': array([-21.17166718, -11.01526988, -39.38372369]),
#  'split181_test_score': array([-1.94217613, -3.62464289, -7.31145961]),
#  'split182_test_score': array([-6.44247204, -7.41269658, -8.7153945 ]),
#  'split183_test_score': array([-20.09747589, -17.97121801,  -0.45049903]),
#  'split184_test_score': array([ -5.52682435, -10.56602375, -13.06168588]),
#  'split185_test_score': array([-0.39256756, -0.26493517, -1.12999425]),
#  'split186_test_score': array([ -2.00441332,  -0.72443794, -12.86370472]),
#  'split187_test_score': array([-23.25700729, -23.45710451, -64.07627573]),
#  'split188_test_score': array([-16.37287592, -27.84673718, -31.59988335]),
#  'split189_test_score': array([-3.66288583, -5.97003843, -5.32777463]),
#  'split190_test_score': array([-0.06580335, -0.19059023, -2.61567595]),
#  'split191_test_score': array([-4.16731293, -2.86208578, -0.65285535]),
#  'split192_test_score': array([-0.10560536, -0.30059176, -1.99822395]),
#  'split193_test_score': array([-24.64245278,  -8.24754113,  -6.84644392]),
#  'split194_test_score': array([ -4.84992265, -10.88173117, -10.01344401]),
#  'split195_test_score': array([-0.12547924, -1.41545877, -3.44909828]),
#  'split196_test_score': array([ -6.44284643,  -8.71845003, -23.89338843]),
#  'split197_test_score': array([-12.84012673,  -6.65710651,  -2.10391923]),
#  'split198_test_score': array([-28.13847482, -31.13785677, -48.82652765]),
#  'split199_test_score': array([-2.91152923, -0.58777588, -0.4449951 ]),
#  'split200_test_score': array([-26.24019333, -26.74508635, -47.70277788]),
#  'split201_test_score': array([-3.78472283e-05, -1.63419926e-01, -1.93382276e+00]),
#  'split202_test_score': array([-10.58305628, -16.71298859,  -8.20098946]),
#  'split203_test_score': array([-3.44727476, -4.40866121, -2.17261033]),
#  'split204_test_score': array([-16.73898239, -15.91803299, -12.44328816]),
#  'split205_test_score': array([-2.70035055, -0.99813674, -1.14985245]),
#  'split206_test_score': array([-0.05820116, -0.16330665, -7.03086646]),
#  'split207_test_score': array([ -9.47092327, -18.0741998 ,  -9.83369773]),
#  'split208_test_score': array([ -2.83950751,  -3.149385  , -34.50909689]),
#  'split209_test_score': array([-1.21230705, -0.04073828, -2.92132549]),
#  'split210_test_score': array([-0.05187917, -0.00968951, -3.29987145]),
#  'split211_test_score': array([ -7.21712957, -21.98076749,  -3.8910251 ]),
#  'split212_test_score': array([-0.00303844, -0.04703065, -0.0796648 ]),
#  'split213_test_score': array([-7.54381420e-03, -3.78119587e-01, -9.15482288e+00]),
#  'split214_test_score': array([-0.1384042 , -0.35422847, -0.56330014]),
#  'split215_test_score': array([-1.12985549, -0.48911155, -5.96959187]),
#  'split216_test_score': array([-2.28574074, -3.74822689, -7.29437466]),
#  'split217_test_score': array([-0.19459114, -0.79019473, -4.0794574 ]),
#  'split218_test_score': array([-183.34532323, -146.22246239,  -41.87411974]),
#  'split219_test_score': array([-51.6546716 , -53.48363144, -58.48665427]),
#  'split220_test_score': array([ -2.21139227,  -3.35593052, -16.52587232]),
#  'split221_test_score': array([ -18.4005116 ,  -58.96067252, -103.06119179]),
#  'split222_test_score': array([-40.85733986, -31.59935593,  -0.05090941]),
#  'split223_test_score': array([ -6.61655539, -13.02409824, -29.45617087]),
#  'split224_test_score': array([-0.06380726, -1.22389107, -0.46273985]),
#  'split225_test_score': array([-39.4165183 , -23.28272245,  -0.16571606]),
#  'split226_test_score': array([ -7.72683137,  -3.51503327, -15.14678473]),
#  'split227_test_score': array([ -8.41200835, -11.64322684, -31.82434668]),
#  'split228_test_score': array([-0.48381649, -0.21322672, -0.03094772]),
#  'split229_test_score': array([-0.17631357, -0.00906941, -2.0396074 ]),
#  'split230_test_score': array([-24.09932227, -28.37400141, -51.94987727]),
#  'split231_test_score': array([-0.70077301, -0.95884107, -0.91347792]),
#  'split232_test_score': array([ -8.42980478,  -0.89293189, -16.84163984]),
#  'split233_test_score': array([ -2.21190573,  -2.04206512, -10.45591032]),
#  'split234_test_score': array([-3.00228833, -0.48020792, -1.10357704]),
#  'split235_test_score': array([ -5.46440509,  -7.0094181 , -25.505183  ]),
#  'split236_test_score': array([-0.73898169, -0.93762447, -9.92689453]),
#  'split237_test_score': array([-5.26747184, -4.64381794, -0.99637539]),
#  'split238_test_score': array([-0.40295258, -2.73139448, -4.33313369]),
#  'split239_test_score': array([-23.17871   , -20.38879659,  -3.65088963]),
#  'split240_test_score': array([-1.01061095, -1.77629723, -0.2294282 ]),
#  'split241_test_score': array([ -9.69237066, -13.74687955, -28.59093635]),
#  'split242_test_score': array([ -2.2353969 ,  -4.23158871, -25.19327053]),
#  'split243_test_score': array([-10.37480359,  -6.84215988,  -0.01496751]),
#  'split244_test_score': array([-10.18961367,  -9.19740795, -16.28103772]),
#  'split245_test_score': array([-0.0753103 , -0.52429958, -9.9527707 ]),
#  'split246_test_score': array([-0.1749356 , -0.61815124, -5.07515287]),
#  'split247_test_score': array([-3.23710238e-01, -1.29331908e-03, -4.04177342e+00]),
#  'split248_test_score': array([-63.59954016, -56.91386077, -14.10579878]),
#  'split249_test_score': array([ -2.63833053, -14.76954871, -24.74262058]),
#  'split250_test_score': array([ -7.15660625, -14.22651661, -17.21923367]),
#  'split251_test_score': array([ -9.29132157,  -7.80005317, -18.64854884]),
#  'split252_test_score': array([-7.59235808, -2.64899111, -0.0204408 ]),
#  'split253_test_score': array([-2.43473847e-04, -2.00826243e-01, -8.78636476e+00]),
#  'split254_test_score': array([-17.61485357, -16.78053845, -41.68409435]),
#  'split255_test_score': array([ -7.3753808 ,  -8.14722536, -17.91306072]),
#  'split256_test_score': array([-6.67988955, -4.76921032, -1.87616672]),
#  'split257_test_score': array([-0.30952018, -0.26768011, -0.09649074]),
#  'split258_test_score': array([-30.94436866, -34.05321894, -47.2273298 ]),
#  'split259_test_score': array([-0.40443331, -0.38368845, -1.66110501]),
#  'split260_test_score': array([-5.12640519, -2.65275732, -3.06983204]),
#  'split261_test_score': array([-1.53452686, -0.87335895, -3.93957959]),
#  'split262_test_score': array([-0.00261891, -0.92434665, -0.22440449]),
#  'split263_test_score': array([-10.18474207, -19.11902591, -26.0867016 ]),
#  'split264_test_score': array([-486.96450658, -144.03024277, -216.01530449]),
#  'split265_test_score': array([ -1.62633847,  -5.71885407, -11.07576266]),
#  'split266_test_score': array([-18.29243008, -19.1814875 , -78.04456759]),
#  'split267_test_score': array([-0.87748556, -1.38169134, -0.1596451 ]),
#  'split268_test_score': array([ -2.45891008,  -4.66721433, -10.59523336]),
#  'split269_test_score': array([-0.40255721, -1.64778148, -0.66686907]),
#  'split270_test_score': array([-1.04908236, -0.09113771, -0.10852781]),
#  'split271_test_score': array([-3.43013525, -0.20337669, -3.21736733]),
#  'split272_test_score': array([-3.81445609, -0.38917392, -4.66157189]),
#  'split273_test_score': array([-2.72877735, -2.81570954, -3.7637935 ]),
#  'split274_test_score': array([-0.95665816, -1.9776195 , -0.27376977]),
#  'split275_test_score': array([-2.5586654 , -2.85119572, -1.48492336]),
#  'split276_test_score': array([-6.03505182e+01, -7.73455501e+00, -3.77183633e-03]),
#  'split277_test_score': array([-30.69213844, -38.88396443, -59.10140865]),
#  'split278_test_score': array([-0.03097781, -0.17775378, -2.56771351]),
#  'split279_test_score': array([-26.32719244, -24.78043911, -43.14545789]),
#  'split280_test_score': array([ -2.46551424,  -4.88154388, -30.87396598]),
#  'split281_test_score': array([-7.80093929, -5.63992067, -9.12153477]),
#  'split282_test_score': array([ -3.69315911,  -3.28178815, -12.29445213]),
#  'split283_test_score': array([-3.71027779, -1.48221563, -0.39336567]),
#  'split284_test_score': array([-4.90283184e-01, -9.08522058e-03, -1.27987363e+01]),
#  'split285_test_score': array([-24.73983658, -25.79784694, -57.45231459]),
#  'split286_test_score': array([-7.41967603, -4.08223923, -0.03336232]),
#  'split287_test_score': array([-23.50815647, -28.86039223, -18.41677421]),
#  'split288_test_score': array([-2.36631096, -0.13608574, -5.64307807]),
#  'split289_test_score': array([-5.05226883, -4.14486628, -0.35552491]),
#  'split290_test_score': array([-6.30505875, -7.80335455, -9.711288  ]),
#  'split291_test_score': array([-0.00188581, -0.57293516, -1.00318041]),
#  'split292_test_score': array([-0.86235057, -1.58904933, -0.85998943]),
#  'split293_test_score': array([ -0.24916675,  -0.38726083, -10.77331142]),
#  'split294_test_score': array([ -6.28770474,  -7.48371436, -39.2972356 ]),
#  'split295_test_score': array([-5.33244244, -1.25351663, -2.37639933]),
#  'split296_test_score': array([-3.5667131 , -4.16380882, -0.53847729]),
#  'split297_test_score': array([-13.6029362 ,  -7.35792808, -15.66154901]),
#  'split298_test_score': array([-2.50101428, -1.22844624, -2.22295366]),
#  'split299_test_score': array([-31.07968454, -33.27694228, -85.00251448]),
#  'split300_test_score': array([-0.00321584, -0.3447716 , -0.47610815]),
#  'split301_test_score': array([-2.16650328, -4.06818107, -2.38759611]),
#  'split302_test_score': array([ -5.91143279,  -5.1654754 , -37.04007242]),
#  'split303_test_score': array([-24.01405608, -18.95547729,  -0.04141766]),
#  'split304_test_score': array([-4.77492944, -3.6369734 , -0.03733808]),
#  'split305_test_score': array([ -2.04895843, -10.91225584, -16.56934784]),
#  'split306_test_score': array([-0.44802422, -5.0769531 , -8.9183601 ]),
#  'split307_test_score': array([ -7.64261289, -15.45300701,  -2.33815989]),
#  'split308_test_score': array([-137.55031866,  -71.04439916,   -2.86761595]),
#  'split309_test_score': array([-22.23870629, -31.11792374, -42.00334989]),
#  'split310_test_score': array([-17.40990841, -14.31162572,  -0.82372822]),
#  'split311_test_score': array([-10.56468704,  -1.13975781,  -1.98996725]),
#  'split312_test_score': array([-24.9448492 , -10.975194  , -30.60712721]),
#  'split313_test_score': array([ -4.44560316,  -6.79712037, -23.0805038 ]),
#  'split314_test_score': array([-0.03350278, -0.00118579, -0.11815566]),
#  'split315_test_score': array([-1.60379453, -0.58868444, -5.83077631]),
#  'split316_test_score': array([-12.35037947,  -5.59917976,  -6.28830821]),
#  'split317_test_score': array([-113.4046691 , -113.53746514, -159.01009528]),
#  'split318_test_score': array([-13.93502552, -27.02924052, -26.39197434]),
#  'split319_test_score': array([ -0.59060608,  -9.22094081, -15.62457336]),
#  'split320_test_score': array([ -2.34867428,  -4.11740045, -12.82495239]),
#  'split321_test_score': array([-59.84345316, -10.6324672 , -38.62764424]),
#  'split322_test_score': array([-21.07268522, -27.22914154, -74.44213912]),
#  'split323_test_score': array([-8.09369507e-01, -2.18032053e-04, -3.68395058e+00]),
#  'split324_test_score': array([-0.024807  , -0.02749081, -0.59371814]),
#  'split325_test_score': array([-0.19069997, -0.00317455, -0.90551483]),
#  'split326_test_score': array([-6.39364543, -1.04750897, -0.99211729]),
#  'split327_test_score': array([-2.01669021, -0.31732127, -3.37265433]),
#  'split328_test_score': array([-1.8367554 , -2.85677747, -0.61750185]),
#  'split329_test_score': array([ -8.22211326, -15.21103871,  -1.47304909]),
#  'split330_test_score': array([-52.94283303, -41.706818  ,  -1.09701095]),
#  'split331_test_score': array([-1.36755408e-03, -1.97703059e+00, -3.55365260e-02]),
#  'split332_test_score': array([ -4.27698542,  -3.57185371, -25.10357745]),
#  'split333_test_score': array([-3.8347824 , -0.04759115, -4.33036321]),
#  'split334_test_score': array([-6.93748209, -4.12504809, -0.15982231]),
#  'split335_test_score': array([-1.03318008, -1.38864651, -1.7500382 ]),
#  'split336_test_score': array([-0.44223937, -0.89102737, -4.12645542]),
#  'split337_test_score': array([-18.26210268, -37.53658278, -43.30056808]),
#  'split338_test_score': array([ -7.12010313, -28.96709381,  -3.59503842]),
#  'split339_test_score': array([-10.41983999, -13.56574233, -15.16630087]),
#  'split340_test_score': array([ -0.15497784, -59.37019777, -80.04868675]),
#  'split341_test_score': array([-11.97788992, -13.67513142,  -1.33758729]),
#  'split342_test_score': array([-0.14745075, -0.31574153, -6.77494345]),
#  'split343_test_score': array([-15.52503279, -16.00408763,  -0.91832477]),
#  'split344_test_score': array([-3.71537712, -5.40606423, -4.3080731 ]),
#  'split345_test_score': array([-14.28612869, -57.4347993 , -59.66077593]),
#  'split346_test_score': array([-59.61542746, -61.56357565, -22.00989903]),
#  'split347_test_score': array([-1.44458258, -0.77965932, -1.51023709]),
#  'split348_test_score': array([-30.63281247, -23.74647743,  -8.29249897]),
#  'split349_test_score': array([-6.23418859, -4.946263  , -2.70380989]),
#  'split350_test_score': array([-0.01153228, -0.04333058, -7.00334832]),
#  'split351_test_score': array([-22.06051731, -25.45628039, -70.90877332]),
#  'split352_test_score': array([-4.27175544, -1.10884984, -0.741603  ]),
#  'split353_test_score': array([ -4.39569598,  -3.2541727 , -16.91702333]),
#  'split354_test_score': array([-5.63701864, -5.16148322, -0.6361922 ]),
#  'split355_test_score': array([-6.22771967, -2.29763523, -0.46084932]),
#  'split356_test_score': array([-0.24337555, -0.39492181, -2.70361346]),
#  'split357_test_score': array([ -3.63264067,  -6.51819857, -16.38518171]),
#  'split358_test_score': array([-1.69074065e-02, -1.62174627e-03, -3.82066965e+00]),
#  'split359_test_score': array([-17.9274191 ,  -3.59337915,  -1.42794286]),
#  'split360_test_score': array([-0.3681828 , -0.11210024, -3.42394546]),
#  'split361_test_score': array([-88.12218522, -72.5046183 , -44.66687461]),
#  'split362_test_score': array([ -65.25009753,  -71.07910141, -106.99187426]),
#  'split363_test_score': array([-2.30248121, -4.47512102, -0.21437404]),
#  'split364_test_score': array([-2.86263359, -0.45676305, -0.70281108]),
#  'split365_test_score': array([-0.16765186, -0.43538552, -0.14680868]),
#  'split366_test_score': array([ -8.78661522,  -2.25128038, -17.80144116]),
#  'split367_test_score': array([-13.97073844, -11.37042807,  -5.88243708]),
#  'split368_test_score': array([-12.23216106, -15.57376323, -31.72202419]),
#  'split369_test_score': array([ -8.60905066, -20.31782558, -42.38740778]),
#  'split370_test_score': array([-5.89900668e-04, -1.34104993e+01, -4.40076264e+01]),
#  'split371_test_score': array([-0.64759271, -0.00850916, -4.97303995]),
#  'split372_test_score': array([-73.72891752, -67.78002243, -36.01784138]),
#  'split373_test_score': array([ -7.05404746, -10.05349967, -17.05220266]),
#  'split374_test_score': array([ -2.23478813,  -2.88771512, -18.12499882]),
#  'split375_test_score': array([-1.72670617, -1.02739287, -5.04521465]),
#  'split376_test_score': array([-1.43538556, -0.85214029, -3.02447872]),
#  'split377_test_score': array([-0.17946567, -0.08834477, -0.43014959]),
#  'split378_test_score': array([ -60.48897922,  -78.66212403, -134.90150171]),
#  'split379_test_score': array([-0.60820394, -0.21113636, -1.43527741]),
#  'split380_test_score': array([-6.00331321, -0.25555111, -0.40881626]),
#  'split381_test_score': array([ -93.08614182, -153.95090572,  -74.5863235 ]),
#  'split382_test_score': array([ -0.68669411,  -3.80874167, -12.88878317]),
#  'split383_test_score': array([ -1.2908384 ,  -7.94977641, -15.09946186]),
#  'split384_test_score': array([-36.61036642, -54.67250782, -62.38941403]),
#  'split385_test_score': array([ -1.80848716,  -4.02199482, -14.01396103]),
#  'split386_test_score': array([-12.20192032, -25.90079942, -12.0006956 ]),
#  'split387_test_score': array([ -0.41181588,  -3.27635155, -13.46307004]),
#  'split388_test_score': array([-1.48491803, -1.05683494, -2.48565884]),
#  'split389_test_score': array([-4.58555649, -0.10494994, -0.15949489]),
#  'split390_test_score': array([-59.82633312, -66.90645445, -56.04350829]),
#  'split391_test_score': array([-4.13895375, -3.83677769, -1.08420179]),
#  'mean_test_score': array([-15.0812939 , -15.18630913, -19.78290173]),
#  'std_test_score': array([41.2004144 , 31.5668894 , 36.13940124]),
#  'rank_test_score': array([1, 2, 3], dtype=int32)}

# %% [markdown]
# ## Video 8: Lasso

# %%
# with lm, MSE is around 31, but with lasso it's much lower. convergence issues cause lasso to get lucky and quit early before overfitting
lm = Pipeline([
    ('josh_transform', PolynomialFeatures(degree = 3, include_bias = False)),
    ('scale', StandardScaler()),
    ('josh_regression', LinearRegression())
])
lm.fit(training_vehicle_data[numeric_features], training_vehicle_data["mpg"])
mean_squared_error(lm.predict(dev_vehicle_data[numeric_features]), dev_vehicle_data["mpg"])
# Out:
# 18.193679879058053

# %%
from sklearn.linear_model import Lasso

scaled_lasso_model = Pipeline([
    ('josh_transform', PolynomialFeatures(degree = 3, include_bias = False)),
    ('scale', StandardScaler()),
    ('josh_lasso', Lasso())
])

parameters_to_try = {'josh_lasso__alpha': 10**np.linspace(-4, 4, 100)}

model_finder = GridSearchCV(estimator = scaled_lasso_model,
                               param_grid = parameters_to_try,
                               scoring = "neg_mean_squared_error",
                               cv=[[training_indices, dev_indices]])
model_finder.fit(vehicle_data[numeric_features], vehicle_data["mpg"])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.063e+03, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.052e+03, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.040e+03, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.025e+03, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.008e+03, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.986e+03, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.960e+03, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.929e+03, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.891e+03, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.832e+03, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.769e+03, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.692e+03, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.603e+03, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.502e+03, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.368e+03, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.211e+03, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.076e+03, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.014e+03, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.651e+02, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.540e+02, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.303e+02, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.091e+02, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.935e+02, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.560e+02, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.391e+02, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.559e+02, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.050e+02, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.296e+01, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.399e+01, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.362e+01, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.419e+01, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.421e+00, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.293e+00, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.507e+00, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.401e+00, tolerance: 1.861e+00
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.435e+03, tolerance: 2.382e+00
# GridSearchCV(cv=[[array([145, 390, 224,  59,  55, 229, 341, 140, 273, 311, 128,  36, 214,
#        369, 263, 313, 158, 233,  71, 148, 213, 185, 156, 354, 312,   0,
#        372,  45, 240, 391, 247, 320, 331, 359, 243, 256,  94, 261, 125,
#        114, 365, 167, 235, 193, 286,  93,  54, 241, 321, 111,  79, 303,
#         82, 228,  37, 131, 246, 178, 370, 309, 144, 382,  13, 376, 310,
#         42, 157, 348, 319, 336, 342, 116, 216, 267, 237, 149, 386, 196,
#        101, 207, 262, 297, 155,  80,  95,   8,...
#        1.38488637e+02, 1.66810054e+02, 2.00923300e+02, 2.42012826e+02,
#        2.91505306e+02, 3.51119173e+02, 4.22924287e+02, 5.09413801e+02,
#        6.13590727e+02, 7.39072203e+02, 8.90215085e+02, 1.07226722e+03,
#        1.29154967e+03, 1.55567614e+03, 1.87381742e+03, 2.25701972e+03,
#        2.71858824e+03, 3.27454916e+03, 3.94420606e+03, 4.75081016e+03,
#        5.72236766e+03, 6.89261210e+03, 8.30217568e+03, 1.00000000e+04])},
#              scoring='neg_mean_squared_error')

# %%
model_finder.best_estimator_.named_steps['josh_lasso'].coef_
# Out:
# array([-7.95206806, -2.70765972, -4.2878518 , -2.99754917, -2.84327527,
#        -2.42622551, -1.33830876,  8.37520517, -0.        ,  2.39565192,
#        -3.23452763,  4.43948954,  0.        ,  0.28356743, -0.57049576,
#        -0.        , -4.26223813, -1.05313044,  0.17398078,  0.        ,
#        -3.82545684, -1.24879275,  2.61529324,  1.76525906,  3.49628931,
#        -0.50881667, -0.90181507,  1.22975842,  1.60737703,  0.        ,
#         1.7836755 ,  3.94772021, -2.71025222, -0.03789689, -0.        ,
#        -0.        , -1.31634806,  3.38918265,  3.41432587, -1.15342026,
#         0.6154467 ,  4.69992345, -1.40914613, -0.68821243, -5.58772732,
#        -0.8319492 , -0.        , -3.71128819,  1.43485194, -0.        ,
#        -0.64370142, -0.32372119, -1.64003059,  5.19216381,  0.41254236])

# %%
best_model = model_finder.best_estimator_

# %%
lasso_weights = pd.DataFrame([best_model.named_steps["josh_lasso"].coef_],
             columns = best_model.named_steps["josh_transform"].get_feature_names_out())

# %% [markdown]
# ### K-Fold Cross Validation

# %%
scaled_ridge_model = Pipeline([
    ('josh_transform', PolynomialFeatures(degree = 3, include_bias = False)),
    ('scale', StandardScaler()),
    ('josh_regression', Ridge())
])

parameters_to_try = {'josh_regression__alpha': [0.001, 1, 1000]}

from sklearn.model_selection import GridSearchCV

model_finder = GridSearchCV(estimator = scaled_ridge_model,
                               param_grid = parameters_to_try,
                               scoring = "neg_mean_squared_error",
                               cv = 5)

model_finder.fit(vehicle_data[numeric_features], vehicle_data["mpg"])
model_finder.cv_results_
# Out:
# {'mean_fit_time': array([0.02976642, 0.02654524, 0.02941175]),
#  'std_fit_time': array([0.00590685, 0.00546999, 0.0135911 ]),
#  'mean_score_time': array([0.00383658, 0.00856967, 0.00432076]),
#  'std_score_time': array([0.00024806, 0.0042218 , 0.00171799]),
#  'param_josh_regression__alpha': masked_array(data=[0.001, 1.0, 1000.0],
#               mask=[False, False, False],
#         fill_value=1e+20),
#  'params': [{'josh_regression__alpha': 0.001},
#   {'josh_regression__alpha': 1},
#   {'josh_regression__alpha': 1000}],
#  'split0_test_score': array([-18.53896299, -12.92016987, -14.84924206]),
#  'split1_test_score': array([-16.08488308, -17.91648827, -18.87742526]),
#  'split2_test_score': array([-10.43515779,  -7.8811933 ,  -9.79665953]),
#  'split3_test_score': array([-11.79765903, -12.4320557 , -20.2963363 ]),
#  'split4_test_score': array([-48.55697894, -50.64783524, -66.99972503]),
#  'mean_test_score': array([-21.08272837, -20.35954848, -26.16387764]),
#  'std_test_score': array([14.04184401, 15.47415718, 20.74123269]),
#  'rank_test_score': array([2, 1, 3], dtype=int32)}

# %%
model_finder
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('josh_transform',
#                                         PolynomialFeatures(degree=3,
#                                                            include_bias=False)),
#                                        ('scale', StandardScaler()),
#                                        ('josh_regression', Ridge())]),
#              param_grid={'josh_regression__alpha': [0.001, 1, 1000]},
#              scoring='neg_mean_squared_error')

# %%
x_values = np.linspace(0, 100, 100) + np.random.random(100)

# %%
y_values = x_values * 13.9 + np.random.random(len(x_values)) * 30

# %%
x_values = x_values / 1000

# %%
x2 = (x_values + np.random.random(100) * 3 * np.mean(x_values)) * 1000

# %%
x3 = (x_values + np.random.random(100) * 3 * np.mean(x_values)) * 1000

# %%
df = pd.DataFrame({"x": x_values, "x2": x2, "x3": x3, "y": y_values})
df
# Out:
#            x          x2          x3            y
# 0   0.000327   19.582711   88.056726    11.853319
# 1   0.001657  130.548372   41.644841    35.241831
# 2   0.002100   32.509799   87.470641    46.252581
# 3   0.003218  139.535202  102.358495    49.120082
# 4   0.004253  107.077193    6.923975    80.662256
# ..       ...         ...         ...          ...
# 95  0.096894  177.603673  226.562081  1375.416579
# 96  0.097420  211.614510  103.492134  1357.601264
# 97  0.098266  214.862042  102.624505  1374.409900
# 98  0.099527  121.970362  209.389334  1399.740637
# 99  0.100706  111.808642  224.562158  1419.897021
#
# [100 rows x 4 columns]

# %%
px.scatter(df, x = "x", y = "y")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7f2a3bf1-66cb-4e7a-b959-21d03ea60593" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7f2a3bf1-66cb-4e7a-b959-21d03ea60593")) {                    Plotly.newPlot(                        "7f2a3bf1-66cb-4e7a-b959-21d03ea60593",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[0.0003273290093433855,0.0016574324612072333,0.002099815137011021,0.003217606020360365,0.004252968979849697,0.00568600478749663,0.006874061294183,0.007233723761515984,0.008822973767331101,0.009202142100380891,0.010295876772863423,0.012033554724513435,0.01227417655170928,0.013732444911086618,0.014254058962225109,0.01573239414881563,0.016747361701959316,0.017295366932543185,0.018663222836120173,0.019614538648697864,0.02039355335200188,0.02201772807390391,0.022748937168851603,0.023756016196282634,0.02436447864065113,0.025982601653275903,0.026705110899070204,0.027861129009527724,0.029211574742004205,0.029674578181379876,0.030723767791115502,0.031899491497153876,0.03307004679017808,0.033396417913218554,0.03532816304135427,0.03619724694931226,0.037344530131589324,0.03814173617537348,0.03903792626999932,0.03998747513592454,0.04075212823979139,0.0423366647023515,0.04276859579815484,0.043943289152397716,0.04521630733852952,0.046121058399262914,0.047237907720785906,0.04820461759764647,0.04866079611896293,0.050189540419902236,0.050819613402767826,0.05217482865232883,0.053149393026532855,0.05374564650648386,0.0550466446844629,0.05610449170195807,0.05722210565588322,0.05787560135519991,0.05923738970015601,0.06004830122297104,0.06099671233080507,0.06250162294432995,0.06263235393538609,0.06422679966332229,0.06529580913511981,0.06654634051025132,0.06681161030068135,0.06785343850341789,0.0692916177093453,0.07047425476695045,0.0714530624468216,0.07263552714495045,0.07319580396580389,0.0741307380022099,0.07482715919390728,0.07653623843917044,0.0768732580560697,0.07813455158983017,0.07879077730927339,0.07993739131981739,0.0812676297935227,0.08199786230584918,0.08363357886734114,0.08456994598849113,0.08530122345632306,0.08596826219523296,0.08748799676729571,0.0880147494324333,0.08893782943877464,0.0902141527412278,0.0910177908893233,0.0925889938118517,0.09333840312943602,0.0947335560917767,0.0954366863140496,0.09689354762416624,0.09741993269234295,0.09826578041622643,0.09952676823411594,0.1007062111152363],"xaxis":"x","y":[11.85331850575006,35.24183118416288,46.25258130033861,49.120081888691914,80.66225593391712,93.69909249816746,123.1670240134171,112.28282400450763,132.301987718257,156.1469381595262,172.2526835230369,189.5272132265712,200.08464100693382,192.60955624035435,203.83268873120832,226.40420053989652,247.39528658377355,249.13827686461286,268.58921213822276,285.1803986799449,291.8084042478229,329.7858604670798,331.73163596166177,336.10866316202345,361.0606244479628,379.8971714488135,394.7182090587971,415.4288735305527,418.763352948921,417.42823047689876,452.23434629389874,446.7257110400372,480.38180939286997,464.7820926586184,510.72522540439314,503.9291194757546,543.8805597390865,533.2517861322606,568.8860660861359,564.1310519833943,578.5920698651768,604.5362947703753,601.3507305298673,621.959302573088,644.4462604127388,653.8473167171886,664.4520021411925,688.9739486302198,687.1526393079769,717.4785024255509,733.5731957042454,742.5025529295893,747.0951397094977,775.8893207120124,787.3236808720328,806.6284315536368,800.5798408054632,818.3738634116826,848.268633187347,859.8534690024322,860.3818205820227,885.0039913362797,885.1686835226972,917.47685152197,924.6674326686743,9 ...

# %%
rm = Ridge(alpha = 10)
rm.fit(df[["x", "x2", "x3"]], df["y"])
df["yhat"] = rm.predict(df[["x", "x2", "x3"]])

# %%
rm.coef_
# Out:
# array([57.60748071,  3.60393313,  3.34658706])

# %%
mean_squared_error(df["y"], df["yhat"])
# Out:
# 79887.52427217203

# %%
px.scatter(df, x = "y", y = "yhat")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d6ce4fd8-d528-481b-b2d4-e889bd7cc9aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d6ce4fd8-d528-481b-b2d4-e889bd7cc9aa")) {                    Plotly.newPlot(                        "d6ce4fd8-d528-481b-b2d4-e889bd7cc9aa",                        [{"hovertemplate":"y=%{x}\u003cbr\u003eyhat=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[11.85331850575006,35.24183118416288,46.25258130033861,49.120081888691914,80.66225593391712,93.69909249816746,123.1670240134171,112.28282400450763,132.301987718257,156.1469381595262,172.2526835230369,189.5272132265712,200.08464100693382,192.60955624035435,203.83268873120832,226.40420053989652,247.39528658377355,249.13827686461286,268.58921213822276,285.1803986799449,291.8084042478229,329.7858604670798,331.73163596166177,336.10866316202345,361.0606244479628,379.8971714488135,394.7182090587971,415.4288735305527,418.763352948921,417.42823047689876,452.23434629389874,446.7257110400372,480.38180939286997,464.7820926586184,510.72522540439314,503.9291194757546,543.8805597390865,533.2517861322606,568.8860660861359,564.1310519833943,578.5920698651768,604.5362947703753,601.3507305298673,621.959302573088,644.4462604127388,653.8473167171886,664.4520021411925,688.9739486302198,687.1526393079769,717.4785024255509,733.5731957042454,742.5025529295893,747.0951397094977,775.8893207120124,787.3236808720328,806.6284315536368,800.5798408054632,818.3738634116826,848.268633187347,859.8534690024322,860.3818205820227,885.0039913362797,885.1686835226972,917.47685152197,924.6674326686743,944.5788463327822,937.3271179371882,972.2726569274207,991.8676277897089,998.908933867923,1017.2400025681951,1026.4391346181417,1044.7435940129674,1047.5431930138072,1046.0905060592747,1083.8366502369079,1075.397345221645,1094.0542430245134,1097.7864134546464,1132.3649029672588,1138.2468196640577,1146.8055835940702,1179.5296521054597,1199.6523341744971,1207.1944404069052,1213.4494247836908,1224.844327828013,1247.8507091788217,1249.9137000410906,1278.5740478238465,1276.9105786205746,1312.8309213983193,1307.4053850678777,1335.4514557196217,1347.8473709566344,1375.416578804153,1357.6012638598343,1374.4099001759034,1399.740636712213,1419.8970207298503],"xaxis":"x","y":[216.48629310041633,461.1543256958754,261.21538139896256,696.8156703312632,260.5188901967002,503.6632294493645,187.84683370767175,536.8548169100385,734.7597504306377,351.25046860386857,665.2392651616458,679.6249389646179,234.52331455645128,422.8723260251229,523.816571786672,512.2854746292186,344.1297866595062,674.4625444665194,15.022291632700046,375.65394815321474,473.4862292790168,276.99156241629635,750.0276005242952,273.82962123719483,535.649373629457,684.9484926067228,113.73299395295328,277.38850684751935,830.4347774469338,664.868893342423,586.972547491097,716.8696884415533,718.1794600796129,560.8450591531137,480.55189744211316,625.145848622445,780.5055707425099,684.3436689164243,1059.3750480965707,356.8485288986384,373.794321303418,749.5601183637585,615.7177060657256,542.0296468731175,959.6012801887603,938.5515175759695,918.3946230892425,574.113314305569,719.2529987388493,826.962797689795,300.2992823573031,798.3331831999227,700.0601809037023,626.9412708799291,658.5896839820628,819.0214216778913,786.6252215192825,1004.8809420733955,505.17674209019833,1081.7384674270197,563.0160036326985,582.7323533309882,710.2623732564731,1200.3455701385897,1241.1563489153393,575.2911557815496,798.2509380461336,777.0136433358196,918.4793215105838,1150.6498328200237,623.9832646195072,763.2895052404883,999.9578742790052,939.600959743444,984.1568715262133,95 ...

# %%
pm = Pipeline([
    ('scaler', StandardScaler()),
    ('josh_regression', Ridge(alpha = 10))
])
pm.fit(df[["x", "x2", "x3"]], df["y"])
df["yhat"] = pm.predict(df[["x", "x2", "x3"]])
mean_squared_error(df["y"], df["yhat"])
# Out:
# 2114.317803105908

# %%
df
# Out:
#            x          x2          x3            y         yhat
# 0   0.000327   19.582711   88.056726    11.853319    57.006323
# 1   0.001657  130.548372   41.644841    35.241831   108.146006
# 2   0.002100   32.509799   87.470641    46.252581    84.318586
# 3   0.003218  139.535202  102.358495    49.120082   161.765057
# 4   0.004253  107.077193    6.923975    80.662256   108.550382
# ..       ...         ...         ...          ...          ...
# 95  0.096894  177.603673  226.562081  1375.416579  1340.619403
# 96  0.097420  211.614510  103.492134  1357.601264  1302.843519
# 97  0.098266  214.862042  102.624505  1374.409900  1314.028717
# 98  0.099527  121.970362  209.389334  1399.740637  1333.216908
# 99  0.100706  111.808642  224.562158  1419.897021  1349.262079
#
# [100 rows x 5 columns]

# %%
pm.named_steps['josh_regression'].coef_
# Out:
# array([341.14444113,  27.14001616,  28.26808806])

# %%
px.line(x = x_values, y = y_values)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3a3997dc-c5b0-4ab9-b5c9-dc4e6834794f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a3997dc-c5b0-4ab9-b5c9-dc4e6834794f")) {                    Plotly.newPlot(                        "3a3997dc-c5b0-4ab9-b5c9-dc4e6834794f",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[0.0003273290093433855,0.0016574324612072333,0.002099815137011021,0.003217606020360365,0.004252968979849697,0.00568600478749663,0.006874061294183,0.007233723761515984,0.008822973767331101,0.009202142100380891,0.010295876772863423,0.012033554724513435,0.01227417655170928,0.013732444911086618,0.014254058962225109,0.01573239414881563,0.016747361701959316,0.017295366932543185,0.018663222836120173,0.019614538648697864,0.02039355335200188,0.02201772807390391,0.022748937168851603,0.023756016196282634,0.02436447864065113,0.025982601653275903,0.026705110899070204,0.027861129009527724,0.029211574742004205,0.029674578181379876,0.030723767791115502,0.031899491497153876,0.03307004679017808,0.033396417913218554,0.03532816304135427,0.03619724694931226,0.037344530131589324,0.03814173617537348,0.03903792626999932,0.03998747513592454,0.04075212823979139,0.0423366647023515,0.04276859579815484,0.043943289152397716,0.04521630733852952,0.046121058399262914,0.047237907720785906,0.04820461759764647,0.04866079611896293,0.050189540419902236,0.050819613402767826,0.05217482865232883,0.053149393026532855,0.05374564650648386,0.0550466446844629,0.05610449170195807,0.05722210565588322,0.05787560135519991,0.05923738970015601,0.06004830122297104,0.06099671233080507,0.06250162294432995,0.06263235393538609,0.06422679966332229,0.06529580913511981,0.06654634051025132,0.06681161030068135,0.06785343850341789,0.0692916177093453,0.07047425476695045,0.0714530624468216,0.07263552714495045,0.07319580396580389,0.0741307380022099,0.07482715919390728,0.07653623843917044,0.0768732580560697,0.07813455158983017,0.07879077730927339,0.07993739131981739,0.0812676297935227,0.08199786230584918,0.08363357886734114,0.08456994598849113,0.08530122345632306,0.08596826219523296,0.08748799676729571,0.0880147494324333,0.08893782943877464,0.0902141527412278,0.0910177908893233,0.0925889938118517,0.09333840312943602,0.0947335560917767,0.0954366863140496,0.09689354762416624,0.09741993269234295,0.09826578041622643,0.09952676823411594,0.1007062111152363],"xaxis":"x","y":[11.85331850575006,35.24183118416288,46.25258130033861,49.120081888691914,80.66225593391712,93.69909249816746,123.1670240134171,112.28282400450763,132.301987718257,156.1469381595262,172.2526835230369,189.5272132265712,200.08464100693382,192.60955624035435,203.83268873120832,226.40420053989652,247.39528658377355,249.13827686461286,268.58921213822276,285.1803986799449,291.8084042478229,329.7858604670798,331.73163596166177,336.10866316202345,361.0606244479628,379.8971714488135,394.7182090587971,415.4288735305527,418.763352948921,417.42823047689876,452.23434629389874,446.7257110400372,480.38180939286997,464.7820926586184,510.72522540439314,503.9291194757546,543.8805597390865,533.2517861322606,568.8860660861359,564.1310519833943,578.5920698651768,604.5362947703753,601.3507305298673,621.959302573088,644.4462604127388,653.8473167171886,664.4520021411925,688.9739486302198,687.1526393079769,717.4785024255509,733.5731957042454,742.5025529295893,747.0951397094977,775.8893207120124,787.3236808720328,806.6284315536368,800.5798408054632,818.3738634116826,848.268633187347,859.8534690024322,860.3818205820227,885.0039913362797,885.1686835226972,917.476851521 ...

# %%
vehicle_data_weight_in_gigatons = vehicle_data.copy()[["weight", "model_year"]]
vehicle_data_weight_in_gigatons["weight"] = vehicle_data_weight_in_gigatons["weight"] / 2204622621848.8
vehicle_data_weight_in_gigatons
# Out:
#            weight  model_year
# 0    1.589388e-09          70
# 1    1.675117e-09          70
# 2    1.558543e-09          70
# 3    1.557183e-09          70
# 4    1.564440e-09          70
# ..            ...         ...
# 393  1.265523e-09          82
# 394  9.661517e-10          82
# 395  1.040994e-09          82
# 396  1.190680e-09          82
# 397  1.233771e-09          82
#
# [392 rows x 2 columns]

# %%
vehicle_data_weight_in_mg = vehicle_data.copy()
vehicle_data_weight_in_mg["weight"] = vehicle_data_weight_in_mg["weight"] * 453592
vehicle_data_weight_in_mg
# Out:
#       mpg  cylinders  displacement     hp      weight  acceleration  \
# 0    18.0          8         307.0  130.0  1589386368          12.0
# 1    15.0          8         350.0  165.0  1675115256          11.5
# 2    18.0          8         318.0  150.0  1558542112          11.0
# 3    16.0          8         304.0  150.0  1557181336          12.0
# 4    17.0          8         302.0  140.0  1564438808          10.5
# ..    ...        ...           ...    ...         ...           ...
# 393  27.0          4         140.0   86.0  1265521680          15.6
# 394  44.0          4          97.0   52.0   966150960          24.6
# 395  32.0          4         135.0   84.0  1040993640          11.6
# 396  28.0          4         120.0   79.0  1190679000          18.6
# 397  31.0          4         119.0   82.0  1233770240          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [392 rows x 9 columns]

# %%
training_vehicle_data = vehicle_data_weight_in_mg

# %%
param_df = pd.DataFrame([get_parameters_and_training_MSE_for_given_alpha(alpha) for alpha in [0.01, 0.1, 1, 10, 100, 1000, 10000, 1e5, 1e6, 1e7, 1e8]],
                        columns = ["alpha", *numeric_features, "Training MSE"])
param_df["1/alpha"] = 1.0/param_df["alpha"]
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=1.78339e-18): result may not be accurate.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=1.7849e-18): result may not be accurate.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=1.79992e-18): result may not be accurate.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=1.9502e-18): result may not be accurate.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=3.45467e-18): result may not be accurate.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=1.85901e-17): result may not be accurate.

# %%
param_df
# Out:
#            alpha  cylinders  displacement        hp        weight  \
# 0   1.000000e-02  -0.397891     -0.000084 -0.045257 -1.143523e-08
# 1   1.000000e-01  -0.397556     -0.000089 -0.045255 -1.143542e-08
# 2   1.000000e+00  -0.394239     -0.000138 -0.045239 -1.143732e-08
# 3   1.000000e+01  -0.363871     -0.000588 -0.045088 -1.145485e-08
# 4   1.000000e+02  -0.205469     -0.002931 -0.044218 -1.155228e-08
# 5   1.000000e+03  -0.038234     -0.005391 -0.042328 -1.171834e-08
# 6   1.000000e+04  -0.004159     -0.006445 -0.038297 -1.190035e-08
# 7   1.000000e+05  -0.000489     -0.008949 -0.022813 -1.261423e-08
# 8   1.000000e+06  -0.000108     -0.005387 -0.005361 -1.502960e-08
# 9   1.000000e+07  -0.000015     -0.000858 -0.000670 -1.658408e-08
# 10  1.000000e+08  -0.000002     -0.000091 -0.000069 -1.683050e-08
#
#     acceleration  Training MSE       1/alpha
# 0      -0.029104     17.761396  1.000000e+02
# 1      -0.029096     17.761396  1.000000e+01
# 2      -0.029021     17.761400  1.000000e+00
# 3      -0.028314     17.761713  1.000000e-01
# 4      -0.023815     17.771526  1.000000e-02
# 5      -0.010978     17.797230  1.000000e-03
# 6       0.000548     17.808517  1.000000e-04
# 7       0.001711     17.907946  1.000000e-05
# 8       0.000475     18.307474  1.000000e-06
# 9       0.000062     18.614347  1.000000e-07
# 10      0.000006     18.669935  1.000000e-08

# %%
param_df = pd.DataFrame([get_parameters_and_training_MSE_for_given_alpha(alpha) for alpha in [0.01, 0.1, 1, 10, 100, 1000, 10000, 1e5, 1e6, 1e7, 1e8]],
                        columns = ["alpha", *numeric_features, "Training MSE"])
param_df["1/alpha"] = 1.0/param_df["alpha"]
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=1.78339e-18): result may not be accurate.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=1.7849e-18): result may not be accurate.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=1.79992e-18): result may not be accurate.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=1.9502e-18): result may not be accurate.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=3.45467e-18): result may not be accurate.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=1.85901e-17): result may not be accurate.

# %%
param_df
# Out:
#            alpha  cylinders  displacement        hp        weight  \
# 0   1.000000e-02  -0.397891     -0.000084 -0.045257 -1.143523e-08
# 1   1.000000e-01  -0.397556     -0.000089 -0.045255 -1.143542e-08
# 2   1.000000e+00  -0.394239     -0.000138 -0.045239 -1.143732e-08
# 3   1.000000e+01  -0.363871     -0.000588 -0.045088 -1.145485e-08
# 4   1.000000e+02  -0.205469     -0.002931 -0.044218 -1.155228e-08
# 5   1.000000e+03  -0.038234     -0.005391 -0.042328 -1.171834e-08
# 6   1.000000e+04  -0.004159     -0.006445 -0.038297 -1.190035e-08
# 7   1.000000e+05  -0.000489     -0.008949 -0.022813 -1.261423e-08
# 8   1.000000e+06  -0.000108     -0.005387 -0.005361 -1.502960e-08
# 9   1.000000e+07  -0.000015     -0.000858 -0.000670 -1.658408e-08
# 10  1.000000e+08  -0.000002     -0.000091 -0.000069 -1.683050e-08
#
#     acceleration  Training MSE       1/alpha
# 0      -0.029104     17.761396  1.000000e+02
# 1      -0.029096     17.761396  1.000000e+01
# 2      -0.029021     17.761400  1.000000e+00
# 3      -0.028314     17.761713  1.000000e-01
# 4      -0.023815     17.771526  1.000000e-02
# 5      -0.010978     17.797230  1.000000e-03
# 6       0.000548     17.808517  1.000000e-04
# 7       0.001711     17.907946  1.000000e-05
# 8       0.000475     18.307474  1.000000e-06
# 9       0.000062     18.614347  1.000000e-07
# 10      0.000006     18.669935  1.000000e-08

# %%
numeric_features = ["cylinders", "displacement", "hp", "weight", "acceleration"]

all_55_features = Pipeline([
    ('josh_transform', PolynomialFeatures(degree = 3, include_bias = False)),
    ('josh_regression', LinearRegression())
])
all_55_features.fit(training_vehicle_data[numeric_features], training_vehicle_data["mpg"])
# Out:
# Pipeline(steps=[('josh_transform',
#                  PolynomialFeatures(degree=3, include_bias=False)),
#                 ('josh_regression', LinearRegression())])

# %%
mean_squared_error(all_55_features.predict(dev_vehicle_data[numeric_features]), dev_vehicle_data["mpg"])
# Out:
# 488.14191030632696

# %%
all_55_features_regularized = Pipeline([
    ('josh_transform', PolynomialFeatures(degree = 3, include_bias = False)),
    ('josh_regression', Ridge(alpha = 100))
])
all_55_features_regularized.fit(training_vehicle_data[numeric_features], training_vehicle_data["mpg"])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=3.66449e-56): result may not be accurate.
# Pipeline(steps=[('josh_transform',
#                  PolynomialFeatures(degree=3, include_bias=False)),
#                 ('josh_regression', Ridge(alpha=100))])

# %%
def get_training_and_dev_MSE(model):
    training_mse = mean_squared_error(model.predict(vehicle_data.iloc[training_indices][numeric_features]),
                                      vehicle_data.iloc[training_indices]["mpg"])
    dev_mse = mean_squared_error(model.predict(vehicle_data.iloc[dev_indices][numeric_features]),
                                      vehicle_data.iloc[dev_indices]["mpg"])
    return training_mse, dev_mse

# %%
get_training_and_dev_MSE(all_55_features)
# Out:
# (506.2501042675676, 488.14191030632696)

# %%
get_training_and_dev_MSE(all_55_features_regularized)
# Out:
# (35174.55686311289, 31509.18307154614)

# %%
def get_training_and_dev_MSEs_for_alpha(alpha):
    all_55_features_regularized = Pipeline([
        ('josh_transform', PolynomialFeatures(degree = 1, include_bias = False)),
        ('scaler', StandardScaler()),
        ('josh_regression', Ridge(alpha = alpha))
    ])
    all_55_features_regularized.fit(vehicle_data.iloc[training_indices][numeric_features], vehicle_data.iloc[training_indices]["mpg"])
    tmse, dmse = get_training_and_dev_MSE(all_55_features_regularized)
    return alpha, tmse, dmse

# %%
get_training_and_dev_MSEs_for_alpha(10)
# Out:
# (10, 17.06993727654615, 21.66552005527506)

# %%
alphas = 10**np.linspace(4, -4, 100)
mses = pd.DataFrame(np.array([get_training_and_dev_MSEs_for_alpha(alpha) for alpha in alphas]),
                    columns = ["alpha", "train MSE", "dev MSE"])

# %%
mses
# Out:
#            alpha  train MSE    dev MSE
# 0   10000.000000  49.726388  62.591636
# 1    8302.175681  48.340678  60.957822
# 2    6892.612104  46.792420  59.127643
# 3    5722.367659  45.084600  57.102642
# 4    4750.810162  43.227937  54.893119
# ..           ...        ...        ...
# 95      0.000210  17.010202  21.460268
# 96      0.000175  17.010202  21.460268
# 97      0.000145  17.010202  21.460267
# 98      0.000120  17.010202  21.460267
# 99      0.000100  17.010202  21.460266
#
# [100 rows x 3 columns]

# %%
px.line(mses, x = "alpha", y = "train MSE", log_x = True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b3eb88b8-6cc7-41ac-b34f-0105dfe3756b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b3eb88b8-6cc7-41ac-b34f-0105dfe3756b")) {                    Plotly.newPlot(                        "b3eb88b8-6cc7-41ac-b34f-0105dfe3756b",                        [{"hovertemplate":"alpha=%{x}\u003cbr\u003etrain MSE=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[10000.0,8302.175681319744,6892.612104349695,5722.3676593502205,4750.810162102798,3944.206059437656,3274.5491628777286,2718.58824273294,2257.019719633919,1873.817422860383,1555.6761439304723,1291.549665014884,1072.2672220103232,890.2150854450383,739.0722033525775,613.5907273413176,509.4138014816375,422.9242874389499,351.1191734215131,291.50530628251755,242.0128264794381,200.92330025650458,166.81005372000593,138.48863713938718,114.97569953977356,95.45484566618337,79.24828983539169,65.79332246575676,54.62277217684337,45.34878508128582,37.64935806792467,31.25715849688235,25.950242113997348,21.54434690031882,17.886495290574334,14.849682622544636,12.32846739442066,10.235310218990259,8.497534359086439,7.054802310718638,5.857020818056661,4.862601580065348,4.037017258596554,3.351602650938841,2.782559402207123,2.310129700083158,1.9179102616724868,1.5922827933410906,1.3219411484660286,1.0974987654930557,0.9111627561154887,0.7564633275546275,0.6280291441834247,0.5214008287999684,0.4328761281083053,0.3593813663804626,0.2983647240283334,0.2477076355991709,0.20565123083486514,0.17073526474706888,0.14174741629268048,0.11768119524349967,0.09770099572992247,0.08111308307896856,0.06734150657750815,0.05590810182512223,0.046415888336127725,0.03853528593710527,0.03199267137797378,0.02656087782946684,0.022051307399030412,0.01830738280295366,0.01519911082952933,0.012618568830660185,0.010476157527896641,0.008697490026177817,0.007220809018385456,0.005994842503189409,0.004977023564332103,0.004132012400115334,0.003430469286314912,0.002848035868435799,0.0023644894126454022,0.0019630406500402682,0.0016297508346206436,0.0013530477745798048,0.0011233240329780265,0.0009326033468832181,0.0007742636826811262,0.0006428073117284306,0.0005336699231206301,0.00044306214575838776,0.00036783797718286266,0.00030538555088334125,0.0002535364493970106,0.00021049041445120176,0.0001747528400007683,0.00014508287784959373,0.00012045035402587811,0.0001],"xaxis":"x","y":[49.72638824606939,48.34067811408557,46.792420241820516,45.08460014755075,43.22793688330507,41.242034127704116,39.1558119140013,37.00689798259183,34.83977606172461,32.702714459904335,30.643793559327626,28.70662925175801,26.92654371200199,25.327885499429676,23.922942992893603,22.712511432108688,21.68779945089485,20.833118908956013,20.128749070430587,19.55348022479349,19.086547304185856,18.70887586593873,18.403720310683116,18.156854014210452,17.956481571486336,17.793010292323405,17.658769701924903,17.547724911698936,17.45520204560241,17.377631521626263,17.312312582382013,17.257203735551602,17.210744325974524,17.171710790099276,17.139107901772306,17.11209199474823,17.089920891556098,17.071924411227474,17.057489551661483,17.04605522160921,17.037112343356533,17.030206098018684,17.024938016115023,17.02096651592051,17.018005305863333,17.015819713036688,17.014221417239355,17.013062251892887,17.01222772469049,17.011630784129885,17.011206184519086,17.010905634117684,17.01069377743496,17.01054497212172,17.010440769667774,17.01036798797416,17.010317262653118,17.010281974027173,17.010257462020956,17.01024045748512,17.010228673735078,17.010220515207717,17.010214870856718,17.010210968344033,17.010208271548645,17.0102064087629 ...

# %%
mean_squared_error(all_55_features_regularized.predict(training_vehicle_data[numeric_features]), training_vehicle_data["mpg"])
# Out:
# 11.257905912038932

# %%
mean_squared_error(all_55_features_regularized.predict(dev_vehicle_data[numeric_features]), dev_vehicle_data["mpg"])
# Out:
# 31509.18307154614

# %%
pipelined_model3_scale_first = Pipeline([
    ('scale', StandardScaler()),
    ('josh_transform', PolynomialFeatures(degree = 3, include_bias = False)),
    ('josh_regression', Ridge(alpha = 1))
])
pipelined_model3_scale_first.fit(training_vehicle_data[numeric_features], training_vehicle_data["mpg"])
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('josh_transform',
#                  PolynomialFeatures(degree=3, include_bias=False)),
#                 ('josh_regression', Ridge(alpha=1))])

# %%
mean_squared_error(pipelined_model3_scale_first.predict(dev_vehicle_data[numeric_features]), dev_vehicle_data["mpg"])
# Out:
# 2717.5535976536185

# %%
pipelined_model3_features_first = Pipeline([
    ('josh_transform', PolynomialFeatures(degree = 3, include_bias = False)),
    ('scale', StandardScaler()),
    ('josh_regression', Ridge(alpha = 1))
])
pipelined_model3_features_first.fit(training_vehicle_data[numeric_features], training_vehicle_data["mpg"])
# Out:
# Pipeline(steps=[('josh_transform',
#                  PolynomialFeatures(degree=3, include_bias=False)),
#                 ('scale', StandardScaler()),
#                 ('josh_regression', Ridge(alpha=1))])

# %%
mean_squared_error(pipelined_model3_features_first.predict(dev_vehicle_data[numeric_features]), dev_vehicle_data["mpg"])
# Out:
# 23.980539938873033

# %%
from sklearn.preprocessing import FunctionTransformer
div100 = FunctionTransformer(lambda x : x, validate=True)

# %%
pipelined_model4_features_first = Pipeline([
    ('div100', div100),
    ('josh_transform', PolynomialFeatures(degree = 8, include_bias = False)),
    ('scale', StandardScaler()),
    ('josh_regression', Ridge(alpha = 1))
])
pipelined_model4_features_first.fit(training_vehicle_data[numeric_features], training_vehicle_data["mpg"])
# Out:
# Pipeline(steps=[('div100',
#                  FunctionTransformer(func=<function <lambda> at 0x78379a51ab90>,
#                                      validate=True)),
#                 ('josh_transform',
#                  PolynomialFeatures(degree=8, include_bias=False)),
#                 ('scale', StandardScaler()),
#                 ('josh_regression', Ridge(alpha=1))])

# %%
mean_squared_error(pipelined_model4_features_first.predict(dev_vehicle_data[numeric_features]), dev_vehicle_data["mpg"])
# Out:
# 117.50227649087907

# %% [markdown]
# ### IGNORE JUST SANITY CHECKING

# %%
best_four
# Out:
#         hp  weight  hp weight    weight^2
# 0    130.0  3504.0   455520.0  12278016.0
# 1    165.0  3693.0   609345.0  13638249.0
# 2    150.0  3436.0   515400.0  11806096.0
# 3    150.0  3433.0   514950.0  11785489.0
# 4    140.0  3449.0   482860.0  11895601.0
# ..     ...     ...        ...         ...
# 387   86.0  2790.0   239940.0   7784100.0
# 388   52.0  2130.0   110760.0   4536900.0
# 389   84.0  2295.0   192780.0   5267025.0
# 390   79.0  2625.0   207375.0   6890625.0
# 391   82.0  2720.0   223040.0   7398400.0
#
# [392 rows x 4 columns]

# %%
vehicle_data_small = vehicle_data.copy().iloc[0:7, :]

# %%
vehicle_data_small["mpg"] = vehicle_data["hp"]

# %%
vehicle_data_small["cylinders"] = -vehicle_data["hp"]

# %%
vehicle_data_small.iloc[5, 3] = -vehicle_data_small.iloc[5, 3]
vehicle_data_small.iloc[6, 3] = -vehicle_data_small.iloc[6, 3]
vehicle_data_small
# Out:
#      mpg  cylinders  displacement     hp  weight  acceleration  model_year  \
# 0  130.0     -130.0         307.0  130.0    3504          12.0          70
# 1  165.0     -165.0         350.0  165.0    3693          11.5          70
# 2  150.0     -150.0         318.0  150.0    3436          11.0          70
# 3  150.0     -150.0         304.0  150.0    3433          12.0          70
# 4  140.0     -140.0         302.0  140.0    3449          10.5          70
# 5  198.0     -198.0         429.0 -198.0    4341          10.0          70
# 6  220.0     -220.0         454.0 -220.0    4354           9.0          70
#
#   origin                       name
# 0    usa  chevrolet chevelle malibu
# 1    usa          buick skylark 320
# 2    usa         plymouth satellite
# 3    usa              amc rebel sst
# 4    usa                ford torino
# 5    usa           ford galaxie 500
# 6    usa           chevrolet impala

# %%
cylmodel = LinearRegression().fit(vehicle_data_small.iloc[0:5][["cylinders"]], vehicle_data_small.iloc[0:5]["mpg"])

# %%
cylmodel.coef_
# Out:
# array([-1.])

# %%
hpmodel = LinearRegression().fit(vehicle_data_small.iloc[0:5][["hp"]], vehicle_data_small.iloc[0:5]["mpg"])

# %%
hpmodel.coef_
# Out:
# array([1.])

# %%
mean_squared_error(cylmodel.predict(vehicle_data_small.iloc[5:7][["cylinders"]]), vehicle_data_small.iloc[5:7]["mpg"])
# Out:
# 8.077935669463161e-28

# %%
cylmodel.predict(vehicle_data_small.iloc[5:7][["cylinders"]])
# Out:
# array([198., 220.])

# %%
hpmodel.predict(vehicle_data_small.iloc[5:7][["hp"]])
# Out:
# array([-198., -220.])

# %%
mean_squared_error(hpmodel.predict(vehicle_data_small.iloc[5:7][["hp"]]), vehicle_data_small.iloc[5:7]["mpg"])
# Out:
# 175207.9999999999

# %%
feature_select = SequentialFeatureSelector(LinearRegression(),
                                           scoring='r2',
                                           cv=[[[0, 1, 2, 3, 4], [5, 6]]],
                                           n_features_to_select = 1)
best_four = pd.DataFrame(feature_select.fit_transform(vehicle_data_small[['hp', 'cylinders']], vehicle_data_small["mpg"]),
                         columns = feature_select.get_feature_names_out())
best_four
# Out:
#    cylinders
# 0     -130.0
# 1     -165.0
# 2     -150.0
# 3     -150.0
# 4     -140.0
# 5     -198.0
# 6     -220.0

# %% [markdown]
# ## Scale vs. No Scale Experiment

# %%
from sklearn.model_selection import GridSearchCV

# %%
model_with_no_scaling = Pipeline([
    ('josh_transform', PolynomialFeatures(degree = 3, include_bias = False)),
    ('scale', StandardScaler()),
    ('josh_regression', Ridge())
])
#model_with_no_scaling.fit(training_vehicle_data[numeric_features], training_vehicle_data["mpg"])

# %%
parameters = {'josh_regression__alpha': [0.001, 0.01, 0.1, 1, 10, 100, 1000]}

lr_model_finder = GridSearchCV(model_with_no_scaling,
                               parameters,
                               scoring = "neg_mean_squared_error",
                               cv=[[training_indices, dev_indices]])

# %%
lr_model_finder.fit(vehicle_data[numeric_features],
                    vehicle_data["mpg"])
# Out:
# GridSearchCV(cv=[[array([145, 390, 224,  59,  55, 229, 341, 140, 273, 311, 128,  36, 214,
#        369, 263, 313, 158, 233,  71, 148, 213, 185, 156, 354, 312,   0,
#        372,  45, 240, 391, 247, 320, 331, 359, 243, 256,  94, 261, 125,
#        114, 365, 167, 235, 193, 286,  93,  54, 241, 321, 111,  79, 303,
#         82, 228,  37, 131, 246, 178, 370, 309, 144, 382,  13, 376, 310,
#         42, 157, 348, 319, 336, 342, 116, 216, 267, 237, 149, 386, 196,
#        101, 207, 262, 297, 155,  80,  95,   8,...
#         89,  91, 334,  77, 377, 137, 190,  87,  41, 335, 231, 122, 294,
#        107, 280, 177,  25, 198, 274,  14, 173,  64, 159, 318,   4, 238,
#        194, 106,  86,  81, 367, 223, 289])]],
#              estimator=Pipeline(steps=[('josh_transform',
#                                         PolynomialFeatures(degree=3,
#                                                            include_bias=False)),
#                                        ('scale', StandardScaler()),
#                                        ('josh_regression', Ridge())]),
#              param_grid={'josh_regression__alpha': [0.001, 0.01, 0.1, 1, 10,
#                                                     100, 1000]},
#              scoring='neg_mean_squared_error')

# %%
lr_model_finder.best_params_
# Out:
# {'josh_regression__alpha': 0.1}

# %%
print(f"MSE: {lr_model_finder.best_score_}")
# Out:
# MSE: -14.934514409527829

# %%
lr_model_finder.best_estimator_
# Out:
# Pipeline(steps=[('josh_transform',
#                  PolynomialFeatures(degree=3, include_bias=False)),
#                 ('scale', StandardScaler()),
#                 ('josh_regression', Ridge(alpha=0.1))])

# %% [markdown]
# # lr_model_finder.predict DON'T DO IT!!!

# %%
lr_model_finder.best_params_
# Out:
# {'josh_regression__alpha': 0.1}

# %%
mean_squared_error(lr_model_finder.predict(vehicle_data.iloc[training_indices][numeric_features]),
                vehicle_data.iloc[training_indices]["mpg"])

# %%
mean_squared_error(lr_model_finder.predict(vehicle_data.iloc[dev_indices][numeric_features]),
                vehicle_data.iloc[dev_indices]["mpg"])

# %%
model_with_no_scaling = Pipeline([
    ('josh_transform', PolynomialFeatures(degree = 3, include_bias = False)),
    ('scale', StandardScaler()),
    ('josh_regression', Ridge(alpha = 0.001))
])
model_with_no_scaling.fit(vehicle_data.iloc[training_indices][numeric_features], vehicle_data.iloc[training_indices]["mpg"])
mean_squared_error(model_with_no_scaling.predict(vehicle_data.iloc[dev_indices][numeric_features]),
                vehicle_data.iloc[dev_indices]["mpg"])

# %% [markdown]
# ### Experiment to see if CV scores match for simpler case

# %%
parameters = {'fit_intercept': [False, True]}

lr_model_finder = GridSearchCV(LinearRegression(),
                               parameters,
                               scoring = "neg_mean_squared_error",
                               cv=[[training_indices, dev_indices]])

lr_model_finder.fit(vehicle_data[["hp"]], vehicle_data["mpg"])

# %%
lr_model_finder.best_params_

# %%
print(f"MSE: {lr_model_finder.best_score_}")

# %%
lr_model_finder.cv_results_

# %%
model = LinearRegression()
model.fit(vehicle_data.iloc[training_indices][["hp"]], vehicle_data.iloc[training_indices]["mpg"])

# %%
mean_squared_error(model.predict(vehicle_data.iloc[training_indices][["hp"]]), vehicle_data.iloc[training_indices]["mpg"])

# %%
mean_squared_error(model.predict(vehicle_data.iloc[dev_indices][["hp"]]), vehicle_data.iloc[dev_indices]["mpg"])

# %%
mean_squared_error(lr_model_finder.predict(vehicle_data.iloc[dev_indices][["hp"]]), vehicle_data.iloc[dev_indices]["mpg"])

# %% [markdown]
# ##### HEY LOOK CROSS VALIDATION JUST LIKE WE EXPECT!

# %%
tiny_vehicle_data = vehicle_data.iloc[0:120]

# %%
tiny_indices = range(0, len(tiny_vehicle_data))
tiny_indices = shuffle(tiny_indices)
num_train = int(np.ceil(len(tiny_indices)*0.6))
tiny_training_indices, tiny_dev_indices = np.split(tiny_indices, [num_train])

# %%
parameters = {'fit_intercept': [False, True]}

lr_model_finder = GridSearchCV(LinearRegression(),
                               parameters,
                               scoring = "neg_mean_squared_error",
                               cv=[[tiny_training_indices, tiny_dev_indices]])

lr_model_finder.fit(tiny_vehicle_data[["hp"]], tiny_vehicle_data["mpg"])

# %%
lr_model_finder.cv_results_

# %%
mean_squared_error(lr_model_finder.predict(tiny_vehicle_data.iloc[tiny_dev_indices][["hp"]]), tiny_vehicle_data.iloc[tiny_dev_indices]["mpg"])

# %%
model = LinearRegression(fit_intercept = True)
model.fit(tiny_vehicle_data.iloc[tiny_training_indices][["hp"]], tiny_vehicle_data.iloc[tiny_training_indices]["mpg"])

# %%
mean_squared_error(model.predict(tiny_vehicle_data.iloc[tiny_training_indices][["hp"]]), tiny_vehicle_data.iloc[tiny_training_indices]["mpg"])

# %%
mean_squared_error(model.predict(tiny_vehicle_data.iloc[tiny_dev_indices][["hp"]]), tiny_vehicle_data.iloc[tiny_dev_indices]["mpg"])

# %% [markdown]
# ### What wait what's the difference between two sections above?

# %%
parameters = {'fit_intercept': [False, True]}

lr_model_finder = GridSearchCV(LinearRegression(),
                               parameters,
                               scoring = "neg_mean_squared_error",
                               cv=[[training_indices, dev_indices]])

lr_model_finder.fit(vehicle_data[["hp"]], vehicle_data["mpg"])
print(f"best score native: {lr_model_finder.best_score_}")
print(f'training score recomputed: {mean_squared_error(lr_model_finder.predict(vehicle_data.iloc[training_indices][["hp"]]), vehicle_data.iloc[training_indices]["mpg"])}')
print(f'dev score recomputed: {mean_squared_error(lr_model_finder.predict(vehicle_data.iloc[dev_indices][["hp"]]), vehicle_data.iloc[dev_indices]["mpg"])}')

# %% [markdown]
# ### An experiment in model variance

# %% [markdown]
# As a sidetrack while trying to verify something about cv score storage, I decided to see the MSE for models fit with the two styles, iloc vs with the data set aside.
#
# What happened was that I saw the MSE you get on your dev set is enormously dependent on the split. This is no surprise since the model has enormous crazy huge variance.

# %%
pipelined_model = Pipeline([
    ('josh_transform', PolynomialFeatures(degree = 3, include_bias = False)),
    ('josh_regression', LinearRegression())
])
pipelined_model.fit(training_vehicle_data[numeric_features], training_vehicle_data["mpg"])

print(f'training MSE: {mean_squared_error(pipelined_model.predict(training_vehicle_data[numeric_features]), training_vehicle_data["mpg"])}')
print(f'dev MSE: {mean_squared_error(pipelined_model.predict(dev_vehicle_data[numeric_features]), dev_vehicle_data["mpg"])}')

# %%
pipelined_model = Pipeline([
    ('josh_transform', PolynomialFeatures(degree = 3, include_bias = False)),
    ('josh_regression', LinearRegression())
])
pipelined_model.fit(vehicle_data.iloc[training_indices][numeric_features], vehicle_data.iloc[training_indices]["mpg"])

print(f'training MSE: {mean_squared_error(pipelined_model.predict(vehicle_data.iloc[training_indices][numeric_features]), vehicle_data.iloc[training_indices]["mpg"])}')
print(f'dev MSE: {mean_squared_error(pipelined_model.predict(vehicle_data.iloc[dev_indices][numeric_features]), vehicle_data.iloc[dev_indices]["mpg"])}')

# %% [markdown]
# ahhh waht is happening??? how is MSE so much worse for the above thing which is EXACTLY THE SAME EXCEPT CHOSEN SAMPLES???

# %%
samples2 = range(0, len(vehicle_data))
samples2 = shuffle(samples2)
training_indices2, dev_indices2 = np.split(samples2, [320])

# %%
training_vehicle_data2 = vehicle_data.iloc[training_indices2]
dev_vehicle_data2 = vehicle_data.iloc[dev_indices2]

pipelined_model = Pipeline([
    ('josh_transform', PolynomialFeatures(degree = 3, include_bias = False)),
    ('josh_regression', LinearRegression())
])
pipelined_model.fit(training_vehicle_data2[numeric_features], training_vehicle_data2["mpg"])

print(f'training MSE: {mean_squared_error(pipelined_model.predict(training_vehicle_data2[numeric_features]), training_vehicle_data2["mpg"])}')
print(f'dev MSE: {mean_squared_error(pipelined_model.predict(dev_vehicle_data2[numeric_features]), dev_vehicle_data2["mpg"])}')

# %%
pipelined_model = Pipeline([
    ('josh_transform', PolynomialFeatures(degree = 3, include_bias = False)),
    ('josh_regression', LinearRegression())
])
pipelined_model.fit(vehicle_data.iloc[training_indices2][numeric_features], vehicle_data.iloc[training_indices2]["mpg"])

print(f'training MSE: {mean_squared_error(pipelined_model.predict(vehicle_data.iloc[training_indices2][numeric_features]), vehicle_data.iloc[training_indices2]["mpg"])}')
print(f'dev MSE: {mean_squared_error(pipelined_model.predict(vehicle_data.iloc[dev_indices2][numeric_features]), vehicle_data.iloc[dev_indices2]["mpg"])}')

# %% [markdown]
# ## SANITY CHECKING CHECK YOUR UNDERSTANDING PROBLEM

# %%
df = pd.DataFrame({'phi1': [1, 1], 'phi2': [-2, 3], 'y': [-3, 12]})

# %%
df

# %%
y_hat = df["phi1"] * 3+ df["phi2"] * 2 - 2
y_hat

# %%
mean_squared_error(df["y"], y_hat)

# %%
2*3**2 + 2*2**2

# %%
26+12.5
