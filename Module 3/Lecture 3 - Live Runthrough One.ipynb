# %% [markdown]
# ### Reading in Data, Basic Queries

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df = pd.read_csv("gdp.csv")

# %%
df

# %%
df["gdp"] = df["GDP (constant 2010 US$)"] / 1_000_000_000

# %%
df

# %%
# See the GDP of only China
df[df["Entity"] == "China"]

# %%
# GDP of China in 2017 using &
df[(df["Entity"] == "China") & (df["Year"] == 2017)]

# %%
# GDP of China in 2017 using query 
df.query('Entity == "China" and Year == 2017')

# %%
# Seeing GDP only from a list of countries using isin
list_of_countries = ["China", "United States", "India", 
                     "Japan", "Germany", "United Kingdom"]
top6 = df[df["Entity"].isin(list_of_countries)]

# %%
top6 = df.query("Entity in @list_of_countries and Year == 2017")

# %% [markdown]
# ### Introducing Our Visualization Libraries

# %%
import matplotlib.pyplot as plt

# %%
top6.plot(x = "Entity", y = "gdp", kind = "bar")

# %%
import seaborn as sns
sns.barplot(data = top6, x = "Entity", y = "gdp")

# %%
sns.barplot(data = top6, x = "Entity", y = "gdp")
plt.xticks(rotation = 45)

# %%
import seaborn as sns
sns.barplot(data = top6, x = "Entity", y = "gdp")
plt.xticks(rotation=45)

# %%
import plotly.express as px

fig = px.bar(top6, x = "Entity", y = "gdp", color = "Entity",
            color_discrete_sequence=px.colors.qualitative.G10)
fig.show()

# %%
list_of_countries = ["China", "United States", "India", 
                     "Japan", "Germany", "United Kingdom"]
top6_over_time = df[df["Entity"].isin(list_of_countries)]

# %%
list_of_countries = ["China", "United States", "India", 
                     "Japan", "Germany", "United Kingdom"]
top6_over_time = df[df["Entity"].isin(list_of_countries)]
fig = px.line(top6_over_time, x = "Year", y = "gdp", color = "Entity", 
            title = "Top 6 Country GDP (in billions)", 
            color_discrete_sequence=px.colors.qualitative.G10)
fig.update_layout(font_size = 16)

fig.show()

# %% [markdown]
# ### Groupby Operations

# %%
# What was the total GDP of the world in each year?

# %%
df.query("Year == 1960")
# Out:
#              Entity Code  Year  GDP (constant 2010 US$)          gdp
# 54          Algeria  DZA  1960             2.743440e+10    27.434399
# 254       Argentina  ARG  1960             1.155739e+11   115.573869
# 341       Australia  AUS  1960             1.992333e+11   199.233335
# 399         Austria  AUT  1960             9.183670e+10    91.836703
# 485         Bahamas  BHS  1960             1.942538e+09     1.942538
# ...             ...  ...   ...                      ...          ...
# 8437  United States  USA  1960             3.078071e+12  3078.071080
# 8509        Uruguay  URY  1960             1.389815e+10    13.898153
# 8637      Venezuela  VEN  1960             1.014246e+11   101.424598
# 8753         Zambia  ZMB  1960             4.592976e+09     4.592976
# 8811       Zimbabwe  ZWE  1960             3.363352e+09     3.363352
#
# [90 rows x 5 columns]

# %%
df.groupby("Year").agg(sum)
# Out:
#       GDP (constant 2010 US$)           gdp
# Year
# 1960             9.025835e+12   9025.834854
# 1961             9.434022e+12   9434.021757
# 1962             9.959005e+12   9959.004555
# 1963             1.047782e+13  10477.823331
# 1964             1.117623e+13  11176.230223
# ...                       ...           ...
# 2013             7.095199e+13  70951.987117
# 2014             7.296737e+13  72967.372451
# 2015             7.462795e+13  74627.950281
# 2016             7.641749e+13  76417.485962
# 2017             7.870927e+13  78709.274760
#
# [58 rows x 2 columns]

# %%
px.line(df.groupby("Year")["gdp"].agg(sum))
# Out:
# <div>                            <div id="6018f6e8-27c4-4799-a339-724341ee906a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
br>Year=%{x}<br>value=%{y}<extra></extra>","legendgroup":"gdp","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"gdp","orientation":"v","showlegend":true,"type":"scatter","x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017],"xaxis":"x","y":[0.09873554136553299,0.103565957762842,0.10863307985335699,0.1140174069702,0.119718140395677,0.12562089234601398,0.13161407054936,0.13638273013080202,0.145260844745812,0.14941653231581203,0.123060442340578,0.120242283951673,0.13476662219913899,0.162946165112038,0.173784126147046,0.160561396944617,0.177222564602279,0.174228788708832,0.17607490534964498,0.155676637732172,0.12997795504384901,0.0711983295137433,0.07463808340905831,0.0862129600892302,0.0895459754388063,0.0839428217051441,0.10454448815575,0.114333776618818,0.12323928795713401,0.12115456130244699,0.021441966957086306,0.022215842920588105,0.022835413140081598,0.023774106416132,0.02621891356127901,0.024906804466891107,0.0234220198970655,0.025764977086841896,0.029758862861818,0.02929349633226921,0.0290091737113651,0.029483214836311104,0.0318083125649755,0.030747970845236103,0.0303322025905471,0.02918572724121581,0.0298099919476302,0.029694454467189598,0.0342340356002484,0.0327164916760401,0.0318235186204366,0.0342153286184383,0.03290299130391141,0.0344088433066358,0.0348726483211879,0.0380610238411092,0.0392161572756995,0.040487383962635494],"yaxis":"y"}],                        {"legend":{"title":{"text":"variable"},"tracegroupgap":0},"margin":{"t":60},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[ ...

# %%
# What was the ratio of the largest to smallest GDP in each year?

# %%
largest_gdps = df.groupby("Year")[["gdp"]].agg(max)
smallest_gdps = df.groupby("Year")[["gdp"]].agg(min)

# %%
ratio_of_largest_to_smallest = largest_gdps / smallest_gdps

# %%
ratio_of_largest_to_smallest
# Out:
#                 gdp
# Year
# 1960   31174.904577
# 1961   30404.457057
# 1962   30754.422037
# 1963   30591.375224
# 1964   30824.487623
# ...             ...
# 2013  459267.263374
# 2014  464801.557315
# 2015  438051.587561
# 2016  431463.180414
# 2017  427416.705791
#
# [58 rows x 1 columns]

# %%
def ratio_of_largest_to_smallest(s):
    largest = max(s)
    smallest = min(s)
    return largest / smallest

# %%
 df.groupby("Year")[["gdp"]].agg(ratio_of_largest_to_smallest)
# Out:
#                 gdp
# Year
# 1960   31174.904577
# 1961   30404.457057
# 1962   30754.422037
# 1963   30591.375224
# 1964   30824.487623
# ...             ...
# 2013  459267.263374
# 2014  464801.557315
# 2015  438051.587561
# 2016  431463.180414
# 2017  427416.705791
#
# [58 rows x 1 columns]

# %%
df.groupby("Entity").agg(ratio_of_largest_to_smallest)
# Out:
#                     Year  GDP (constant 2010 US$)        gdp
# Entity
# Afghanistan     1.007493                 2.741642   2.741642
# Albania         1.018687                 3.344123   3.344123
# Algeria         1.029082                10.473116  10.473116
# American Samoa  1.006993                 1.181962   1.181962
# Andorra         1.023858                 3.937261   3.937261
# ...                  ...                      ...        ...
# Venezuela       1.027551                 4.323108   4.323108
# Vietnam         1.016633                 7.802018   7.802018
# Yemen           1.013065                 2.635640   2.635640
# Zambia          1.029082                 6.198730   6.198730
# Zimbabwe        1.029082                 4.766613   4.766613
#
# [202 rows x 3 columns]

# %%
# What was the smallest economy in each year?

# %%
df.groupby("Year").agg(min)
# Out:
#            Entity Code  GDP (constant 2010 US$)       gdp
# Year
# 1960      Algeria  ARG             9.873554e+07  0.098736
# 1961      Algeria  ARG             1.035660e+08  0.103566
# 1962      Algeria  ARG             1.086331e+08  0.108633
# 1963      Algeria  ARG             1.140174e+08  0.114017
# 1964      Algeria  ARG             1.197181e+08  0.119718
# ...           ...  ...                      ...       ...
# 2013  Afghanistan  AFG             3.440884e+07  0.034409
# 2014  Afghanistan  AFG             3.487265e+07  0.034873
# 2015  Afghanistan  AFG             3.806102e+07  0.038061
# 2016  Afghanistan  AFG             3.921616e+07  0.039216
# 2017  Afghanistan  AFG             4.048738e+07  0.040487
#
# [58 rows x 4 columns]

# %%
df.sort_values("gdp")
# Out:
#              Entity Code  Year  GDP (constant 2010 US$)           gdp
# 8241         Tuvalu  TUV  1990             2.144197e+07      0.021442
# 8242         Tuvalu  TUV  1991             2.221584e+07      0.022216
# 8243         Tuvalu  TUV  1992             2.283541e+07      0.022835
# 8247         Tuvalu  TUV  1996             2.342202e+07      0.023422
# 8244         Tuvalu  TUV  1993             2.377411e+07      0.023774
# ...             ...  ...   ...                      ...           ...
# 8490  United States  USA  2013             1.580286e+13  15802.855301
# 8491  United States  USA  2014             1.620886e+13  16208.861247
# 8492  United States  USA  2015             1.667269e+13  16672.691918
# 8493  United States  USA  2016             1.692033e+13  16920.327942
# 8494  United States  USA  2017             1.730498e+13  17304.984279
#
# [8869 rows x 5 columns]

# %%
def get_first_item(s):
    return s.iloc[0]

# %%
df.sort_values("gdp").groupby("Year").agg(get_first_item)
# Out:
#       Entity Code  GDP (constant 2010 US$)       gdp
# Year
# 1960  Belize  BLZ             9.873554e+07  0.098736
# 1961  Belize  BLZ             1.035660e+08  0.103566
# 1962  Belize  BLZ             1.086331e+08  0.108633
# 1963  Belize  BLZ             1.140174e+08  0.114017
# 1964  Belize  BLZ             1.197181e+08  0.119718
# ...      ...  ...                      ...       ...
# 2013  Tuvalu  TUV             3.440884e+07  0.034409
# 2014  Tuvalu  TUV             3.487265e+07  0.034873
# 2015  Tuvalu  TUV             3.806102e+07  0.038061
# 2016  Tuvalu  TUV             3.921616e+07  0.039216
# 2017  Tuvalu  TUV             4.048738e+07  0.040487
#
# [58 rows x 4 columns]

# %%
df.sort_values("gdp").groupby("Year").first()
# Out:
#       Entity Code  GDP (constant 2010 US$)       gdp
# Year
# 1960  Belize  BLZ             9.873554e+07  0.098736
# 1961  Belize  BLZ             1.035660e+08  0.103566
# 1962  Belize  BLZ             1.086331e+08  0.108633
# 1963  Belize  BLZ             1.140174e+08  0.114017
# 1964  Belize  BLZ             1.197181e+08  0.119718
# ...      ...  ...                      ...       ...
# 2013  Tuvalu  TUV             3.440884e+07  0.034409
# 2014  Tuvalu  TUV             3.487265e+07  0.034873
# 2015  Tuvalu  TUV             3.806102e+07  0.038061
# 2016  Tuvalu  TUV             3.921616e+07  0.039216
# 2017  Tuvalu  TUV             4.048738e+07  0.040487
#
# [58 rows x 4 columns]

# %%
df[df["Entity"] == "Tuvalu"]
# Out:
#       Entity Code  Year  GDP (constant 2010 US$)       gdp
# 8241  Tuvalu  TUV  1990             2.144197e+07  0.021442
# 8242  Tuvalu  TUV  1991             2.221584e+07  0.022216
# 8243  Tuvalu  TUV  1992             2.283541e+07  0.022835
# 8244  Tuvalu  TUV  1993             2.377411e+07  0.023774
# 8245  Tuvalu  TUV  1994             2.621891e+07  0.026219
# ...      ...  ...   ...                      ...       ...
# 8264  Tuvalu  TUV  2013             3.440884e+07  0.034409
# 8265  Tuvalu  TUV  2014             3.487265e+07  0.034873
# 8266  Tuvalu  TUV  2015             3.806102e+07  0.038061
# 8267  Tuvalu  TUV  2016             3.921616e+07  0.039216
# 8268  Tuvalu  TUV  2017             4.048738e+07  0.040487
#
# [28 rows x 5 columns]

# %%
# What fraction of world GDP did each country generate each year?

# %%
df
# Out:
#            Entity Code  Year  GDP (constant 2010 US$)        gdp
# 0     Afghanistan  AFG  2002             8.013233e+09   8.013233
# 1     Afghanistan  AFG  2003             8.689884e+09   8.689884
# 2     Afghanistan  AFG  2004             8.781610e+09   8.781610
# 3     Afghanistan  AFG  2005             9.762979e+09   9.762979
# 4     Afghanistan  AFG  2006             1.030523e+10  10.305228
# ...           ...  ...   ...                      ...        ...
# 8864     Zimbabwe  ZWE  2013             1.418193e+10  14.181927
# 8865     Zimbabwe  ZWE  2014             1.448359e+10  14.483588
# 8866     Zimbabwe  ZWE  2015             1.472830e+10  14.728302
# 8867     Zimbabwe  ZWE  2016             1.481899e+10  14.818986
# 8868     Zimbabwe  ZWE  2017             1.532981e+10  15.329811
#
# [8869 rows x 5 columns]

# %%
total_gdp
# Out:
#       GDP (constant 2010 US$)           gdp
# Year
# 1960             9.025835e+12   9025.834854
# 1961             9.434022e+12   9434.021757
# 1962             9.959005e+12   9959.004555
# 1963             1.047782e+13  10477.823331
# 1964             1.117623e+13  11176.230223
# ...                       ...           ...
# 2013             7.095199e+13  70951.987117
# 2014             7.296737e+13  72967.372451
# 2015             7.462795e+13  74627.950281
# 2016             7.641749e+13  76417.485962
# 2017             7.870927e+13  78709.274760
#
# [58 rows x 2 columns]

# %%
chinese_gdp_indexed_by_year = df.query('Entity == "China"').set_index("Year")

# %%
chinese_gdp_indexed_by_year
# Out:
#      Entity Code  GDP (constant 2010 US$)           gdp
# Year
# 1960  China  CHN             1.279381e+11    127.938142
# 1961  China  CHN             9.304941e+10     93.049411
# 1962  China  CHN             8.785725e+10     87.857254
# 1963  China  CHN             9.690655e+10     96.906551
# 1964  China  CHN             1.145242e+11    114.524162
# ...     ...  ...                      ...           ...
# 2013  China  CHN             7.766513e+12   7766.512756
# 2014  China  CHN             8.333287e+12   8333.286913
# 2015  China  CHN             8.908301e+12   8908.300778
# 2016  China  CHN             9.505157e+12   9505.156931
# 2017  China  CHN             1.016101e+13  10161.012759
#
# [58 rows x 4 columns]

# %%
chinese_gdp_indexed_by_year / total_gdp
# Out:
#       Code  Entity  GDP (constant 2010 US$)       gdp
# Year
# 1960   NaN     NaN                 0.014175  0.014175
# 1961   NaN     NaN                 0.009863  0.009863
# 1962   NaN     NaN                 0.008822  0.008822
# 1963   NaN     NaN                 0.009249  0.009249
# 1964   NaN     NaN                 0.010247  0.010247
# ...    ...     ...                      ...       ...
# 2013   NaN     NaN                 0.109462  0.109462
# 2014   NaN     NaN                 0.114206  0.114206
# 2015   NaN     NaN                 0.119369  0.119369
# 2016   NaN     NaN                 0.124385  0.124385
# 2017   NaN     NaN                 0.129095  0.129095
#
# [58 rows x 4 columns]

# %%
px.line( (chinese_gdp_indexed_by_year / total_gdp)["gdp"])
# Out:
# <div>                            <div id="ce594758-6cd5-4e63-a0e8-7e61e6e3928c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce594758-6cd5-4e63-a0e8-7e61e6e3928c")) {                    Plotly.newPlot(                        "ce594758-6cd5-4e63-a0e8-7e61e6e3928c",                        [{"hovertemplate":"variable=gdp<br>Year=%{x}<br>value=%{y}<extra></extra>","legendgroup":"gdp","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"gdp","orientation":"v","showlegend":true,"type":"scatter","x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017],"xaxis":"x","y":[0.014174660233226374,0.009863175361214827,0.008821891117922361,0.009248729236067309,0.010247119076892035,0.011332124221876145,0.011834923407613997,0.010678116095272755,0.0095798512327925,0.010554275243466756,0.010856549825231897,0.011141552293616023,0.010935803030160002,0.01105940276173966,0.011085923692053355,0.011927279331932003,0.011144077147750975,0.011532841651025198,0.012390646848763457,0.012801584136951162,0.01332809389492569,0.013747735708580693,0.01491566583066976,0.016141213167619708,0.017769127809758485,0.019428011303543234,0.020477436271833183,0.0219112941219569,0.023281864262850605,0.02243930054572831,0.022248305427147484,0.02391840392899442,0.026786045079677273,0.0300345046182423,0.03295960133026807,0.03537877185176222,0.03761074444383754,0.03961676274164876,0.041670912294379275,0.04341784246497668,0.0450922847340527,0.04792633097359721,0.051189408649909875,0.05474016874451876,0.05771491266008808,0.0619263384664582,0.06692673384900738,0.07335948708298554,0.07899817775240676,0.08795093215823692,0.09329603492622639,0.09907092136508112,0.10424137740948505,0.10946152562435826,0.11420565978482429,0.11936949554381351,0.12438458045336229,0.1290954946529727],"yaxis":"y"}],                        {"legend":{"title":{"text":"variable"},"tracegroupgap":0},"margin":{"t":60},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#4603 ...

# %%
df.set_index("Year")
# Out:
#            Entity Code  GDP (constant 2010 US$)        gdp
# Year
# 2002  Afghanistan  AFG             8.013233e+09   8.013233
# 2003  Afghanistan  AFG             8.689884e+09   8.689884
# 2004  Afghanistan  AFG             8.781610e+09   8.781610
# 2005  Afghanistan  AFG             9.762979e+09   9.762979
# 2006  Afghanistan  AFG             1.030523e+10  10.305228
# ...           ...  ...                      ...        ...
# 2013     Zimbabwe  ZWE             1.418193e+10  14.181927
# 2014     Zimbabwe  ZWE             1.448359e+10  14.483588
# 2015     Zimbabwe  ZWE             1.472830e+10  14.728302
# 2016     Zimbabwe  ZWE             1.481899e+10  14.818986
# 2017     Zimbabwe  ZWE             1.532981e+10  15.329811
#
# [8869 rows x 4 columns]

# %%
df.set_index("Year") / total_gdp
# Out:
#       Code  Entity  GDP (constant 2010 US$)       gdp
# Year
# 1960   NaN     NaN                 0.003040  0.003040
# 1960   NaN     NaN                 0.012805  0.012805
# 1960   NaN     NaN                 0.022074  0.022074
# 1960   NaN     NaN                 0.010175  0.010175
# 1960   NaN     NaN                 0.000215  0.000215
# ...    ...     ...                      ...       ...
# 2017   NaN     NaN                 0.000836  0.000836
# 2017   NaN     NaN                 0.000010  0.000010
# 2017   NaN     NaN                 0.002227  0.002227
# 2017   NaN     NaN                 0.000358  0.000358
# 2017   NaN     NaN                 0.000195  0.000195
#
# [8869 rows x 4 columns]

# %%
df_indexed_by_year_and_entity = df.set_index(["Year", "Entity"]) 
df_indexed_by_year_and_entity
# Out:
#                  Code  GDP (constant 2010 US$)        gdp
# Year Entity
# 2002 Afghanistan  AFG             8.013233e+09   8.013233
# 2003 Afghanistan  AFG             8.689884e+09   8.689884
# 2004 Afghanistan  AFG             8.781610e+09   8.781610
# 2005 Afghanistan  AFG             9.762979e+09   9.762979
# 2006 Afghanistan  AFG             1.030523e+10  10.305228
# ...               ...                      ...        ...
# 2013 Zimbabwe     ZWE             1.418193e+10  14.181927
# 2014 Zimbabwe     ZWE             1.448359e+10  14.483588
# 2015 Zimbabwe     ZWE             1.472830e+10  14.728302
# 2016 Zimbabwe     ZWE             1.481899e+10  14.818986
# 2017 Zimbabwe     ZWE             1.532981e+10  15.329811
#
# [8869 rows x 3 columns]

# %%
share_of_world_economy_by_year_and_entity = (df_indexed_by_year_and_entity / total_gdp)[["gdp"]]
share_of_world_economy_by_year_and_entity
# Out:
#                        gdp
# Year Entity
# 2002 Afghanistan  0.000155
# 2003 Afghanistan  0.000163
# 2004 Afghanistan  0.000158
# 2005 Afghanistan  0.000169
# 2006 Afghanistan  0.000171
# ...                    ...
# 2013 Zimbabwe     0.000200
# 2014 Zimbabwe     0.000198
# 2015 Zimbabwe     0.000197
# 2016 Zimbabwe     0.000194
# 2017 Zimbabwe     0.000195
#
# [8869 rows x 1 columns]

# %%
share_of_world_economy = share_of_world_economy_by_year_and_entity.reset_index()
share_of_world_economy
# Out:
#       Year       Entity       gdp
# 0     2002  Afghanistan  0.000155
# 1     2003  Afghanistan  0.000163
# 2     2004  Afghanistan  0.000158
# 3     2005  Afghanistan  0.000169
# 4     2006  Afghanistan  0.000171
# ...    ...          ...       ...
# 8864  2013     Zimbabwe  0.000200
# 8865  2014     Zimbabwe  0.000198
# 8866  2015     Zimbabwe  0.000197
# 8867  2016     Zimbabwe  0.000194
# 8868  2017     Zimbabwe  0.000195
#
# [8869 rows x 3 columns]

# %%
top6_share = share_of_world_economy[share_of_world_economy["Entity"].isin(list_of_countries)]
top6_share
# Out:
#       Year         Entity       gdp
# 1726  1960          China  0.014175
# 1727  1961          China  0.009863
# 1728  1962          China  0.008822
# 1729  1963          China  0.009249
# 1730  1964          China  0.010247
# ...    ...            ...       ...
# 8490  2013  United States  0.222726
# 8491  2014  United States  0.222138
# 8492  2015  United States  0.223411
# 8493  2016  United States  0.221420
# 8494  2017  United States  0.219860
#
# [338 rows x 3 columns]

# %%
px.line(top6_share, x = "Year", y = "gdp", color = "Entity")
# Out:
# <div>                            <div id="fe0f9150-ca37-4adb-af56-1f499b16365f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f
# 8494  United States  USA  2017             1.730498e+13  17304.984279
#
# [338 rows x 5 columns]

# %%
top6_by_entity_and_year = top6_all_time.set_index(["Entity", "Year"])
top6_by_entity_and_year
# Out:
#                    Code  GDP (constant 2010 US$)           gdp
# Entity        Year
# China         1960  CHN             1.279381e+11    127.938142
#               1961  CHN             9.304941e+10     93.049411
#               1962  CHN             8.785725e+10     87.857254
#               1963  CHN             9.690655e+10     96.906551
#               1964  CHN             1.145242e+11    114.524162
# ...                 ...                      ...           ...
# United States 2013  USA             1.580286e+13  15802.855301
#               2014  USA             1.620886e+13  16208.861247
#               2015  USA             1.667269e+13  16672.691918
#               2016  USA             1.692033e+13  16920.327942
#               2017  USA             1.730498e+13  17304.984279
#
# [338 rows x 3 columns]

# %%
top6_all_time.groupby("Entity").first()
# Out:
#                Code  Year  GDP (constant 2010 US$)          gdp
# Entity
# China           CHN  1960             1.279381e+11   127.938142
# Germany         DEU  1970             1.534053e+12  1534.052735
# India           IND  1960             1.367463e+11   136.746336
# Japan           JPN  1960             7.962132e+11   796.213204
# United Kingdom  GBR  1960             7.245584e+11   724.558361
# United States   USA  1960             3.078071e+12  3078.071080

# %%
gdp1960_values_by_entity = top6_all_time.query("Year == 1960").set_index(["Entity"])
gdp1960_values_by_entity
# Out:
#                Code  Year  GDP (constant 2010 US$)          gdp
# Entity
# China           CHN  1960             1.279381e+11   127.938142
# India           IND  1960             1.367463e+11   136.746336
# Japan           JPN  1960             7.962132e+11   796.213204
# United Kingdom  GBR  1960             7.245584e+11   724.558361
# United States   USA  1960             3.078071e+12  3078.071080

# %%
top6_by_entity_and_year["gdp_ratio"] = top6_by_entity_and_year["gdp"] / gdp1960_values_by_entity["gdp"]
top6_by_entity_and_year
# Out:
#                    Code  GDP (constant 2010 US$)           gdp  gdp_ratio
# Entity        Year
# China         1960  CHN             1.279381e+11    127.938142   1.000000
#               1961  CHN             9.304941e+10     93.049411   0.727300
#               1962  CHN             8.785725e+10     87.857254   0.686717
#               1963  CHN             9.690655e+10     96.906551   0.757448
#               1964  CHN             1.145242e+11    114.524162   0.895153
# ...                 ...                      ...           ...        ...
# United States 2013  USA             1.580286e+13  15802.855301   5.134012
#               2014  USA             1.620886e+13  16208.861247   5.265915
#               2015  USA             1.667269e+13  16672.691918   5.416604
#               2016  USA             1.692033e+13  16920.327942   5.497056
#               2017  USA             1.730498e+13  17304.984279   5.622022
#
# [338 rows x 4 columns]

# %%
top6_including_gdp_ratio = top6_by_entity_and_year.reset_index()

# %%
px.line(top6_including_gdp_ratio, x = "Year", y = "gdp_ratio", color = "Entity")
# Out:
# <div>                            <div id="540b23d1-f1ed-4df2-9bfe-91ff82dfea49" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("540b23d1-f1ed-4df2-9bfe-91ff82dfea49")) {                    Plotly.newPlot(                        "540b23d1-f1ed-4df2-9bfe-91ff82dfea49",                        [{"hovertemplate":"Entity=China<br>Year=%{x}<br>gdp_ratio=%{y}<extra></extra>","legendgroup":"China","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"China","orientation":"v","showlegend":true,"type":"scatter","x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017],"xaxis":"x","y":[1.0,0.7272999999605393,0.6867166600344816,0.7574484759855915,0.8951526088758576,1.0468809761026563,1.158373800101279,1.0915356317864968,1.0467826709690289,1.2241076553904557,1.460360432834982,1.5634618794420785,1.6230297770215272,1.748976887745091,1.7893782538605933,1.9454120376057378,1.9148690685618155,2.0598246570360823,2.3001370668644627,2.47494748394617,2.668158997562777,2.8061672215746447,3.0568821618628768,3.388101899491359,3.9010324654021367,4.425463716647234,4.821087292147913,5.384620873529713,5.989556922115069,6.240271862403294,6.48408639149093,7.086722303009424,8.094182338296047,9.216649226925888,10.419620912896075,11.560488898060818,12.708257294426145,13.881327198527043,14.969292031153948,16.117060427519274,17.48564198230364,18.9439288826958,20.673631956977893,22.748355591289517,25.048492658154057,27.902962758132855,31.452074252304755,35.928140984422946,39.396747681254574,43.09996835890643,47.684141533167235,52.23151251435824,56.33495704164448,60.70521746868699,65.13528145946795,69.62974928812112,74.29494249042517,79.42129352226434],"yaxis":"y"},{"hovertemplate":"Entity=Germany<br>Year=%{x}<br>gdp_ratio=%{y}<extra></extra>","legendgroup":"Germany","line":{"color":"#EF553B","dash":"solid"},"mode":"lines","name":"Germany","orientation":"v","showlegend":true,"type":"scatter","x":[1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017],"xaxis":"x","y":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"yaxis":"y"},{"hovertemplate":"Entity=India<br>Year=%{x}<br>gdp_ratio=%{y}<extra></extra>","legendgroup":"India","line":{"color":"#00cc96","dash":"solid"},"mode":"lines","name":"India","orientation":"v","showlegend":true,"type":"scatter","x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017],"xaxis":"x","y":[1.0,1.037227425326978,1.06762988608298,1.1316273929742888,1.2159670181432836,1.1839169229333792,1.1832618762641007,1.2758635132525178,1.319088865463976,1.4053533239069271,1.4778306234244831,1.5021103517591141,1.4937991554694765,1.5430276223557695,1.5613176882706068,1.7041768830189747,1.7325191107347835,1.858209293623196,1.9643600958022225,1.8614633250434218,1.9868481724274922,2.1061823193595774,2.179387598335152,2.338240826280841,2.4275788786943733,2.5551311368628267,2.677178615255226,2.783338268304991,3.0513120347024434,3.232784037422887,3.411668673255686,3.4477242 ...

# %%
# Plot only the countries with large gdp growth since 1960

# %%
df_by_entity_and_year = df.set_index(["Entity", "Year"])
gdp1960_values_by_entity = df.query("Year == 1960").set_index(["Entity"])
df_by_entity_and_year["gdp_ratio"] = df_by_entity_and_year["gdp"] / gdp1960_values_by_entity["gdp"]
df_with_gdp_ratio = df_by_entity_and_year.reset_index()
df_with_gdp_ratio
# Out:
#            Entity  Year Code  GDP (constant 2010 US$)        gdp  gdp_ratio
# 0     Afghanistan  2002  AFG             8.013233e+09   8.013233        NaN
# 1     Afghanistan  2003  AFG             8.689884e+09   8.689884        NaN
# 2     Afghanistan  2004  AFG             8.781610e+09   8.781610        NaN
# 3     Afghanistan  2005  AFG             9.762979e+09   9.762979        NaN
# 4     Afghanistan  2006  AFG             1.030523e+10  10.305228        NaN
# ...           ...   ...  ...                      ...        ...        ...
# 8864     Zimbabwe  2013  ZWE             1.418193e+10  14.181927   4.216605
# 8865     Zimbabwe  2014  ZWE             1.448359e+10  14.483588   4.306296
# 8866     Zimbabwe  2015  ZWE             1.472830e+10  14.728302   4.379055
# 8867     Zimbabwe  2016  ZWE             1.481899e+10  14.818986   4.406017
# 8868     Zimbabwe  2017  ZWE             1.532981e+10  15.329811   4.557897
#
# [8869 rows x 6 columns]

# %%
df_with_gdp_ratio = df_with_gdp_ratio.dropna()
df_with_gdp_ratio
# Out:
#         Entity  Year Code  GDP (constant 2010 US$)        gdp  gdp_ratio
# 54     Algeria  1960  DZA             2.743440e+10  27.434399   1.000000
br>Year=%{x}<br>gdp_ratio=%{y}<extra></extra>","legendgroup":"Australia","line":{"color":"#00cc96","dash":"solid"},"mode":"lines","name":"Australia","showlegend":true,"type":"scattergl","x":[1960,1961,1962,1963,1964,1965,19 ...

# %%
df_with_gdp_ratio.query("Year == 2017 and gdp_ratio > 10")
# Out:
#             Entity  Year Code  GDP (constant 2010 US$)           gdp  \
# 638     Bangladesh  2017  BGD             1.799922e+11    179.992152
# 826         Belize  2017  BLZ             1.616833e+09      1.616833
# 1116      Botswana  2017  BWA             1.724066e+10     17.240661
# 1314  Burkina Faso  2017  BFA             1.321529e+10     13.215294
# 1783         China  2017  CHN             1.016101e+13  10161.012759
# ...            ...   ...  ...                      ...           ...
# 7185    Seychelles  2017  SYC             1.341523e+09      1.341523
# 7301     Singapore  2017  SGP             3.099957e+11    309.995673
# 7494   South Korea  2017  KOR             1.345946e+12   1345.945672
# 7927      Thailand  2017  THA             4.229004e+11    422.900352
# 8209        Turkey  2017  TUR             1.205787e+12   1205.786798
#
#       gdp_ratio
# 638   10.076512
# 826   16.375388
# 1116  84.096474
# 1314  11.456717
# 1783  79.421294
# ...         ...
# 7185  11.369219
# 7301  55.549158
# 7494  56.985728
# 7927  27.039889
# 8209  13.823725
#
# [26 rows x 6 columns]

# %%
def max_gdp_ratio_gt_10(s):
    max_gdp_ratio = max(s["gdp_ratio"])
    return max_gdp_ratio > 10

# %%
ratio_greater_than_10 = df_with_gdp_ratio.groupby("Entity").filter(max_value_greater_than_10)
ratio_greater_than_10
# Out:
#           Entity  Year Code  GDP (constant 2010 US$)          gdp  gdp_ratio
# 581   Bangladesh  1960  BGD             1.786255e+10    17.862545   1.000000
# 582   Bangladesh  1961  BGD             1.894469e+10    18.944687   1.060582
# 583   Bangladesh  1962  BGD             1.997775e+10    19.977747   1.118415
# 584   Bangladesh  1963  BGD             1.988667e+10    19.886669   1.113317
# 585   Bangladesh  1964  BGD             2.206481e+10    22.064814   1.235256
# ...          ...   ...  ...                      ...          ...        ...
# 8205      Turkey  2013  TUR             9.750871e+11   975.087052  11.178871
# 8206      Turkey  2014  TUR             1.025467e+12  1025.466785  11.756449
# 8207      Turkey  2015  TUR             1.087876e+12  1087.875531  12.471933
# 8208      Turkey  2016  TUR             1.122512e+12  1122.511655  12.869019
# 8209      Turkey  2017  TUR             1.205787e+12  1205.786798  13.823725
#
# [1508 rows x 6 columns]

# %%
px.line(ratio_greater_than_10, y = "gdp_ratio", x = "Year", color = "Entity")
# Out:
# <div>                            <div id="8416758a-2f42-4bdc-bce5-27f6f8affaec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8416758a-2f42-4bdc-bce5-27f6f8affaec")) {                    Plotly.newPlot(                        "8416758a-2f42-4bdc-bce5-27f6f8affaec",                        [{"hovertemplate":"Entity=Bangladesh<br>Year=%{x}<br>gdp_ratio=%{y}<extra></extra>","legendgroup":"Bangladesh","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"Bangladesh","showlegend":true,"type":"scattergl","x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017],"xaxis":"x","y":[1.